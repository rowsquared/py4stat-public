# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Task 1: Load both datasets
cities_url = "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_populated_places.zip"
countries_url = "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"

cities = gpd.read_file(cities_url)
countries = gpd.read_file(countries_url)

print(f"Total cities: {len(cities)}")
print(f"Cities columns: {cities.columns.tolist()[:10]}...")  # First 10 columns
print(f"\nTotal countries: {len(countries)}")

# Task 2: Filter to cities with population > 1 million
# The population column is 'POP_MAX' or 'POP_MIN'
major_cities = cities[cities['POP_MAX'] > 1_000_000].copy()
print(f"\nCities with pop > 1M: {len(major_cities)}")

# Task 3: Spatial join - add country info to each city
# YOUR CODE HERE - use gpd.sjoin()
# Hint: cities are points, countries are polygons
# Use predicate='within' to find which country each city is within
cities_with_country = # YOUR CODE HERE

print(f"\nAfter spatial join: {len(cities_with_country)} cities")
print("\nSample of joined data:")
print(cities_with_country[['NAME_left', 'POP_MAX', 'NAME_right']].head(10))

# Task 4: Which country has the most million+ cities?
# YOUR CODE HERE - use value_counts() or groupby()
country_counts = # YOUR CODE HERE

print("\nCountries with most million+ population cities:")
print(country_counts.head(10))

# Task 5: Create a map
fig, ax = plt.subplots(figsize=(15, 10))

# Plot country boundaries
countries.plot(ax=ax, color='lightgray', edgecolor='white')

# Plot cities as points, sized by population
# YOUR CODE HERE - plot major_cities with markersize based on population
major_cities.plot(ax=ax, color='red', markersize=major_cities['POP_MAX']/500000,
                  alpha=0.6)

ax.set_title('World Cities with Population > 1 Million')
ax.axis('off')
plt.show()
