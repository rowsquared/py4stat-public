# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Task 1: Load the Natural Earth countries dataset
# Option A: Download the zip file and load locally
# Option B: Load directly from URL (may be slow)
url = "https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_countries.zip"
countries = gpd.read_file(url)

# Task 2: Explore the data structure
print(f"Number of countries: {len(countries)}")
print(f"\nColumns available:")
# YOUR CODE HERE - print column names

print(f"\nCRS: {countries.crs}")
print(f"\nFirst few rows:")
# YOUR CODE HERE - show head()

# Task 3: Filter to African countries only
# Hint: Use the 'CONTINENT' column
africa = # YOUR CODE HERE

print(f"\nAfrican countries: {len(africa)}")

# Task 4: Create a map of Africa colored by population
fig, ax = plt.subplots(figsize=(10, 10))
# YOUR CODE HERE - use africa.plot() with column='POP_EST'
ax.set_title('African Countries by Population')
ax.axis('off')
plt.show()

# Task 5: Find the 5 most populous African countries
top_5 = # YOUR CODE HERE - sort and select top 5
print("\nTop 5 most populous African countries:")
print(top_5[['NAME', 'POP_EST']])
# Out:
#   Cell In[1], line 21
#     africa = # YOUR CODE HERE
#              ^
# SyntaxError: invalid syntax
