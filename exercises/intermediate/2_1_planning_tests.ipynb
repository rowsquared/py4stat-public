# %%
import unittest

# The function specification (not implemented - we're just planning tests)
def validate_household_record(record):
    """
    Validate a household survey record.

    Parameters:
        record: dict with keys 'hh_id', 'province', 'hh_size', 'monthly_income'

    Returns:
        tuple: (is_valid: bool, errors: list of error messages)

    Validation rules:
        - hh_id must be a non-empty string
        - province must be one of: NTH, STH, EST, WST, CTR, LKS
        - hh_size must be an integer between 1 and 30
        - monthly_income must be a non-negative number
    """
    pass  # Implementation to be tested

# Task 1: Normal cases (valid records)
# Example: {"hh_id": "HH-001", "province": "CTR", "hh_size": 4, "monthly_income": 35000}
normal_cases = [
    # YOUR TEST CASES HERE
]

# Task 2: Edge cases (boundary conditions)
edge_cases = [
    # YOUR TEST CASES HERE
]

# Task 3: Error cases (invalid inputs)
error_cases = [
    # YOUR TEST CASES HERE
]

# Task 4: Combination cases (multiple failures)
combination_cases = [
    # YOUR TEST CASES HERE
]

# Task 5: Test class skeleton
class TestHouseholdValidation(unittest.TestCase):
    """Tests for household record validation."""

    # Add your test method stubs here
    # Example:
    # def test_valid_typical_household(self):
    #     """A typical valid household should pass validation."""
    #     pass

    pass
