# %%
# Exercise 1.1 - Introduction to Classes for Survey Data
# Create a class to represent Census Enumeration Areas

class EnumerationArea:
    """A class representing a census enumeration area in Datania."""

    def __init__(self, ea_code, province, district, expected_households, is_urban):
        # Task 1: Store all the attributes
        # YOUR CODE HERE
        pass

    def summary(self):
        # Task 2: Return a formatted summary string
        # Example: "EA CTR-NUM-001 (Central Province, Numerica Urban): 45 households, Urban"
        # YOUR CODE HERE
        pass

    def is_complete(self):
        # Task 3: Check if all required data is valid
        # YOUR CODE HERE
        pass


# Task 4: Create at least 3 enumeration areas from different provinces
# Use Datania geography: provinces are NTH, STH, EST, WST, CTR, LKS
# Districts include: Numerica Urban, Polaris District, Median Urban, etc.

# YOUR CODE HERE


# Print summaries and validation status for each EA
# YOUR CODE HERE
