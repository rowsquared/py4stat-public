# %% [markdown]
# # Lesson 2.1: Loading Data and First Diagnostics
#
# Dataset folder: `../data/fake_data`
#
# Goal: perform first diagnostics and identify data quality issues, including sentinel missing codes.

# %%
import os
import pandas as pd

DATA_DIR = '../data/fake_data'
households_path = os.path.join(DATA_DIR, 'datania_households_raw.csv')

households = pd.read_csv(households_path)
households.head()

# %% [markdown]
# ## Exercise 1 - Basic diagnostics
# Tasks:
# 1. Print shape and columns.
# 2. Run `.info()`.
# 3. Run `.describe(include='all')`.
# 4. Write 3 suspicious findings.

# %%
# TODO: add diagnostics code

# %% [markdown]
# ## Exercise 2 - Preserve IDs as text
# Reload with explicit dtypes for `hh_id` and `region_code`, then verify dtypes.

# %%
# TODO: reload with explicit dtypes for hh_id and region_code

# %% [markdown]
# ## Exercise 3 - Invalid district and duplicate IDs
# Tasks:
# 1. Filter rows with `district == 'Polaris District'`.
# 2. Find duplicated `hh_id` rows.

# %%
# TODO: create `polaris_rows`
# TODO: create `dup_ids`
# Tip: use boolean filtering and `.duplicated(..., keep=False)`

# %% [markdown]
# ## Exercise 4 - Sentinel-coded missing values
# Check these sentinel codes:
# - `hh_size = 99`
# - `education_code = 99`
# - `age = 999`
# - `pop_density = 9999`
# - `income_dkw` that becomes `999999` after numeric conversion

# %%
# TODO: clean/convert income_dkw to numeric in a temporary series
# TODO: count each sentinel code and store in `sentinel_report`
# sentinel_report = {...}
# pd.Series(sentinel_report)
