# %% [markdown]
# # Lesson 2 - Datania Household Budget Analyzer
#
# **Topic:** Functions + `for` loop + `if` statements
#
# This exercise is adapted to the Datania household-survey context used in Lesson 2.

# %% [markdown]
# ## Data
# Use this synthetic Datania household snapshot:

# %%
households = [
    {'hh_id': 'HH0001', 'district': 'Kurtosis Bay', 'income_dkw': 3200, 'expenses_dkw': 2500, 'members': 4},
    {'hh_id': 'HH0002', 'district': 'Vector Hills', 'income_dkw': 1800, 'expenses_dkw': 2100, 'members': 3},
    {'hh_id': 'HH0003', 'district': 'Omega Town', 'income_dkw': 4500, 'expenses_dkw': 3700, 'members': 6},
    {'hh_id': 'HH0004', 'district': 'Nu Station', 'income_dkw': 2600, 'expenses_dkw': 2400, 'members': 2},
    {'hh_id': 'HH0005', 'district': 'Gamma Plains', 'income_dkw': 1500, 'expenses_dkw': 1400, 'members': 5},
]

# %% [markdown]
# ## Task
# Write a function:
#
# ```python
# def analyze_households(data):
#     ...
# ```
#
# Inside the function, use a `for` loop and `if` statements to:
#
# 1. Calculate each household's balance: `income_dkw - expenses_dkw`.
# 2. Count how many are:
#    - `"stable"` if balance >= 500
#    - `"warning"` if 0 <= balance < 500
#    - `"deficit"` if balance < 0
# 3. Create a list of household IDs in deficit.
# 4. Create a list of `priority_support` household IDs where:
#    - `members >= 5` **and** `balance < 500`
#
# Return a dictionary like:
#
# ```python
# {
#     'stable': ...,
#     'warning': ...,
#     'deficit': ...,
#     'deficit_households': [...],
#     'priority_support': [...]
# }
# ```

# %%
def analyze_households(data):
    # TODO: initialize counters

    # TODO: initialize lists

    # TODO: loop through each household
    # for hh in data:
    #     balance = ...
    #
    #     TODO: classify into stable / warning / deficit
    #
    #     TODO: collect deficit household IDs
    #
    #     TODO: collect priority_support IDs
    #
    #     BONUS: print one sentence per household

    # TODO: return the result dictionary
    pass

# %% [markdown]
# ## Run your function
# After implementing `analyze_households`, run this cell:

# %%
# TODO: run and inspect your report
# report = analyze_households(households)
# print(report)
