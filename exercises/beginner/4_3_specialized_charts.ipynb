# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import datania

# ============================================
# TASK 1: Population Pyramid
# ============================================

# Load census data
census_data = datania.generate_census_data(n_persons=2000, seed=42)
census_df = pd.read_csv(census_data)

print("Census data preview:")
print(census_df[['person_id', 'age', 'sex']].head())

# Create age groups
age_bins = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 80, 100]
age_labels = ['0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
              '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79', '80+']

census_df['age_group'] = pd.cut(census_df['age'], bins=age_bins, labels=age_labels, right=False)

# Count by age group and sex
pyramid_data = census_df.groupby(['age_group', 'sex']).size().unstack(fill_value=0)
print("\nPyramid data:")
print(pyramid_data)

# Create the population pyramid
# YOUR CODE HERE
# Hint: Use go.Figure() with two go.Bar() traces
# - Males: negative x values, orientation='h'
# - Females: positive x values, orientation='h'

fig = go.Figure()

# Add Male bars (negative values for left side)
# fig.add_trace(go.Bar(...))

# Add Female bars (positive values for right side)
# fig.add_trace(go.Bar(...))

# Update layout
# fig.update_layout(...)

# fig.show()


# ============================================
# TASK 2: Sankey Diagram
# ============================================

# Load labour force data
qlfs_data = datania.generate_labour_force_survey(n_persons=1000, seed=42)
qlfs_df = pd.read_csv(qlfs_data)

print("\n" + "="*50)
print("QLFS data preview:")
print(qlfs_df[['person_id', 'education_level', 'employment_status']].head())

# Prepare flow data: count people by education -> employment
flow_data = qlfs_df.groupby(['education_level', 'employment_status']).size().reset_index(name='count')
print("\nFlow data:")
print(flow_data)

# Create node labels
education_levels = flow_data['education_level'].unique().tolist()
employment_statuses = flow_data['employment_status'].unique().tolist()
all_labels = education_levels + employment_statuses

print(f"\nNodes: {all_labels}")

# Create source and target indices
# YOUR CODE HERE
# Hint: source_indices = [education_levels.index(edu) for edu in flow_data['education_level']]
# target_indices = [len(education_levels) + employment_statuses.index(emp) for emp in ...]

# Create Sankey diagram
# fig = go.Figure(data=[go.Sankey(...)])
# fig.show()


# ============================================
# TASK 3: Treemap
# ============================================

# Load household data
hh_data = datania.generate_household_survey(n_households=600, seed=42)
hh_df = pd.read_csv(hh_data)

print("\n" + "="*50)
print("Household data preview:")
print(hh_df[['hh_id', 'province', 'dwelling_type', 'monthly_income']].head())

# Prepare treemap data
treemap_data = hh_df.groupby(['province', 'dwelling_type']).agg({
    'hh_id': 'count',
    'monthly_income': 'mean'
}).reset_index()
treemap_data.columns = ['province', 'dwelling_type', 'count', 'avg_income']

print("\nTreemap data:")
print(treemap_data.head(10))

# Create treemap
# YOUR CODE HERE
# fig = px.treemap(
#     treemap_data,
#     path=['province', 'dwelling_type'],
#     values='count',
#     ...
# )
# fig.show()
