# %%
import datania
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Load data
qlfs_data = datania.generate_labour_force_survey(n_persons=800, seed=42)
df = pd.read_csv(qlfs_data)

print("Dataset shape:", df.shape)
print("\nEmployment status distribution:")
print(df['employment_status'].value_counts())

# Task 1: Create binary target
# YOUR CODE HERE
df['is_employed'] = ___

# Task 2 & 3: Select and encode features
features_to_use = ['age', 'education_level', 'urban_rural', 'province', 'sex']

# Create feature DataFrame with encoding
# Hint: Use pd.get_dummies() for categorical columns
# YOUR CODE HERE

# Create X and y
# YOUR CODE HERE

# Task 4: Train/test split
# Hint: Use stratify=y to preserve class distribution
X_train, X_test, y_train, y_test = train_test_split(
    ___,  # YOUR CODE HERE
    test_size=0.2,
    random_state=42,
    stratify=___  # YOUR CODE HERE
)

print(f"\nTraining samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}")

# Task 5: Calculate baseline accuracy
# Hint: What percentage belongs to the majority class?
most_common_class = ___  # YOUR CODE HERE
baseline_accuracy = ___  # YOUR CODE HERE

print(f"\nBaseline accuracy (always predict majority class): {baseline_accuracy:.2%}")

# Task 6: Verify class distribution in train and test
print(f"\n% employed in training set: {y_train.mean():.2%}")
print(f"% employed in test set: {y_test.mean():.2%}")
