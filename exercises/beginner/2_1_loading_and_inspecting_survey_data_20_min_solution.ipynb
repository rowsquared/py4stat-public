# %%
import datania

qlfs_data = datania.generate_labour_force_survey(n_persons=800, seed=42)

# %%
import pandas as pd
import datania

# Step 1: Generate and load the data
# The datania function returns a CSV-like StringIO object
csv_file = datania.generate_labour_force_survey(n_persons=800, seed=42)
df = pd.read_csv(csv_file)

# Step 2: Check the structure with df.info()
# YOUR CODE HERE
df.info()

# Step 3: Generate summary statistics
# YOUR CODE HERE
df.describe()

# Step 4: Visual inspection
# YOUR CODE HERE
import matplotlib.pyplot as plt
df.hist()
plt.tight_layout()

# Step 5: Write your summary as comments
# Total records:
# Columns with missing values:
# Data type issues noticed:
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   person_id          800 non-null    str
#  1   hh_id              800 non-null    str
#  2   province           800 non-null    str
#  3   district           800 non-null    str
#  4   urban_rural        800 non-null    str
#  5   age                800 non-null    int64
#  6   sex                800 non-null    str
#  7   education_level    708 non-null    str
#  8   employment_status  800 non-null    str
#  9   occupation_code    498 non-null    float64
#  10  occupation_desc    498 non-null    str
#  11  industry_code      498 non-null    str
#  12  industry_desc      498 non-null    str
#  13  sector             498 non-null    str
#  14  hours_worked       498 non-null    float64
#  15  monthly_income     498 non-null    float64
#  16  is_informal        498 non-null    object
# ...
