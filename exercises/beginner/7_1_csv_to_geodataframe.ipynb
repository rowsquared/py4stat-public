# %%
from pathlib import Path

import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt

# Download remote source files (only if missing) so the notebook can continue to load them from the local data folder.
import urllib.request

rootPath = Path().cwd().parent.parent

download_plan = [
    ("https://py4statdata.rowsquared.org/api/public/dl/XR6oc32H?inline=true",
     rootPath.joinpath("data", "power_plants", "african_power_plants.csv")),
    ("https://py4statdata.rowsquared.org/api/public/dl/OemlZbgA?inline=true",
     rootPath.joinpath("data", "geo", "africa", "africa.geojson")),
]

for url, dest_path in download_plan:
    dest_path.parent.mkdir(parents=True, exist_ok=True)
    if not dest_path.exists():
        try:
            print(f"Downloading {url} -> {dest_path}")
            # urlretrieve will follow redirects and save to the destination path
            urllib.request.urlretrieve(url, str(dest_path))
            print(f"Saved: {dest_path}")
        except Exception as e:
            print(f"Failed to download {url}: {e}")
    else:
        print(f"Already exists, skipping: {dest_path}")

# %%
rootPath = Path().cwd().parent.parent
power_plants_data_path = rootPath.joinpath("data", "power_plants", "african_power_plants.csv")


# Load the African power plants data
power_plants = pd.read_csv(power_plants_data_path, low_memory=False)

print("Columns:", power_plants.columns.tolist())
print(f"Shape: {power_plants.shape}")
power_plants.head()

# Task 1: Inspect the coordinate columns
# YOUR CODE HERE — look at the latitude and longitude columns, check for missing values

# Task 2: Naive scatterplot — longitude on X, latitude on Y
# Does the result look like Africa?
plt.figure(figsize=(10, 8))

# YOUR CODE HERE — use plt.scatter()

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Power Plants — Scatterplot Check')
plt.show()

# Task 3: Create Point geometries
# IMPORTANT: Point() takes (longitude, latitude) — X before Y!
# YOUR CODE HERE
geometry = # Create a list of Point objects using zip()


# Task 4: Convert to GeoDataFrame
# YOUR CODE HERE
power_plants_gdf = # Create GeoDataFrame with geometry and CRS

print(power_plants_gdf.head())
print(f"\nCRS: {power_plants_gdf.crs}")
print(f"Geometry column: {power_plants_gdf.geometry.name}")

# Task 5: Load country boundaries and plot them
# YOUR CODE HERE — use gpd.read_file() and .plot()




# Task 6: Save as GeoPackage
# YOUR CODE HERE

print("GeoPackage saved successfully!")
