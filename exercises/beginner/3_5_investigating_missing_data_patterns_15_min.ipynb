# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datania

# Generate base data with missing values
survey_data = datania.generate_household_survey(n_households=800, seed=789)
df = pd.read_csv(survey_data)

# Introduce realistic missing patterns
np.random.seed(42)
df.loc[(df['province'] == 'STH') & (np.random.random(len(df)) < 0.15), 'monthly_income'] = np.nan
df.loc[(df['monthly_income'] > 60000) & (np.random.random(len(df)) < 0.25), 'monthly_income'] = np.nan

print(f"Total households: {len(df)}")

# Task 1: Count missing values per column
# Calculate count and percentage missing for each column
# YOUR CODE HERE


# Task 2: Missing income by province
# Create income_missing flag and calculate % missing by province
# YOUR CODE HERE


# Task 3: Compare characteristics
# Compare average household size between missing and non-missing income
# YOUR CODE HERE


# Task 4: Your assessment
# Is this MCAR, MAR, or MNAR? Why does it matter?
# YOUR ANSWER HERE
