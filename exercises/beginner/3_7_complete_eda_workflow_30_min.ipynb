# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datania

# Load the data
agri_data = datania.generate_agricultural_survey(n_farms=600, seed=2026)
df = pd.read_csv(agri_data)

print("=" * 50)
print("DATANIA AGRICULTURAL PRODUCTION SURVEY - EDA")
print("=" * 50)

# ============================================
# TASK 1: DATA OVERVIEW
# ============================================
print("\n--- TASK 1: Data Overview ---")

# Number of farms, columns, and missing values
# YOUR CODE HERE


# ============================================
# TASK 2: UNIVARIATE ANALYSIS
# ============================================
print("\n--- TASK 2: Univariate Analysis ---")

# Summary statistics for area_hectares and yield_kg_per_ha
# YOUR CODE HERE


# Histograms
# YOUR CODE HERE


# Boxplots to check for outliers
# YOUR CODE HERE


# ============================================
# TASK 3: AGGREGATION BY REGION
# ============================================
print("\n--- TASK 3: Regional Analysis ---")

# Average yield by province with multiple statistics
# YOUR CODE HERE


# ============================================
# TASK 4: RELATIONSHIP EXPLORATION
# ============================================
print("\n--- TASK 4: Relationship Exploration ---")

# Compare yield between farms using fertilizer vs not
# YOUR CODE HERE


# Cross-tabulation of province and crop_name
# YOUR CODE HERE


# ============================================
# TASK 5: EDA DOCUMENTATION
# ============================================
print("\n--- TASK 5: EDA Summary ---")

# Write your EDA summary below
# Format: 🔴 Issues | 🟡 Outliers | 🟢 Patterns | ➡️ Recommendations

eda_summary = """
# EDA Summary: Datania Agricultural Production Survey

**Date:** [TODAY]
**Analyst:** [YOUR NAME]
**Dataset:** agricultural_survey (600 farms)

## 🔴 Data Quality Issues
- [YOUR FINDINGS]

## 🟡 Outliers & Unusual Values
- [YOUR FINDINGS]

## 🟢 Key Patterns
- [YOUR FINDINGS]

## ➡️ Recommendations
- [YOUR RECOMMENDATIONS]
"""

print(eda_summary)
# Out:
# ...
# DATANIA AGRICULTURAL PRODUCTION SURVEY - EDA
# ...
#
# --- TASK 1: Data Overview ---
#
# --- TASK 2: Univariate Analysis ---
#
# --- TASK 3: Regional Analysis ---
#
# --- TASK 4: Relationship Exploration ---
#
# --- TASK 5: EDA Summary ---
#
# # EDA Summary: Datania Agricultural Production Survey
#
# **Date:** [TODAY]
# **Analyst:** [YOUR NAME]
# **Dataset:** agricultural_survey (600 farms)
#
# ## 🔴 Data Quality Issues
# - [YOUR FINDINGS]
#
# ## 🟡 Outliers & Unusual Values
# - [YOUR FINDINGS]
#
# ## 🟢 Key Patterns
# - [YOUR FINDINGS]
#
# ## ➡️ Recommendations
# - [YOUR RECOMMENDATIONS]
