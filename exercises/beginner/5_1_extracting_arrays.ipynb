# %%
import pandas as pd
import numpy as np
import datania

# Load household survey data
survey_data = datania.generate_household_survey(n_households=800, seed=42)
df = pd.read_csv(survey_data)

print("Data loaded successfully!")
print(f"Shape: {df.shape}")
print(f"Columns: {list(df.columns)}")

# Task 1: Extract monthly_income as NumPy array
# YOUR CODE HERE
income_array = ___

# Task 2: Print array attributes
print("\n--- Array Attributes ---")
# YOUR CODE HERE: print shape, dtype, ndim

# Task 3: Extract multiple columns as 2D array
feature_columns = ["monthly_income", "hh_size", "monthly_expenditure"]
# YOUR CODE HERE
X = ___

# Task 4: Verify shape
print(f"\n2D Array shape: {X.shape}")
# Check: should be (800, 3)
assert X.shape == (800, 3), "Shape mismatch!"
print("✓ Shape verified!")

# Task 5: Compare pandas and NumPy mean calculations
pandas_mean = df["monthly_income"].mean()
numpy_mean = ___  # YOUR CODE HERE

print(f"\nPandas mean: {pandas_mean:,.2f}")
print(f"NumPy mean: {numpy_mean:,.2f}")
print(f"Match: {np.isclose(pandas_mean, numpy_mean)}")
