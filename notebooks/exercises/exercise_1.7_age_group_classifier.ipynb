# %% [markdown]
# ## Exercise 1.7 - Age Group Classifier ~15 min
#
# ### Scenario
#
# You are preparing data for the Datania Population and Housing Census report. One common task is classifying individuals into standard age groups for demographic analysis. You need to write code that assigns people to the correct age group and determines their eligibility for various programs based on their age and other characteristics.
#
# ### Dataset
#
# No external dataset needed - you will work with sample age values and create classification logic.
#
# ### Tasks
#
# 1. Write an `if-elif-else` statement to classify an age into one of these groups:
#    - "Child (0-14)"
#    - "Youth (15-24)"
#    - "Working Age (25-64)"
#    - "Elderly (65+)"
# 2. Determine program eligibility: A person is eligible for the "Youth Employment Program" if they are between 15-35 AND currently unemployed. Test with different combinations.
# 3. Use a ternary operator to assign "Urban" or "Rural" based on a boolean variable `is_urban`.
# 4. Classify a list of ages using a list comprehension with conditional logic.

# %%
# Exercise 1.7 - Age Group Classifier
# Datania National Statistics Office

# Task 1: Classify a single age into age groups
print("Task 1: Age Group Classification")
print("-" * 35)

age = 42  # Try changing this value to test different cases

# YOUR CODE HERE - write if-elif-else to classify the age
if ____:
    age_group = "Child (0-14)"
elif ____:
    age_group = "Youth (15-24)"
elif ____:
    age_group = "Working Age (25-64)"
else:
    age_group = "Elderly (65+)"

print(f"Age {age} → {age_group}")

# Test with a few more ages
test_ages = [5, 18, 42, 70]
for test_age in test_ages:
    # YOUR CODE HERE - repeat the classification for each test_age
    pass  # Replace this with your code

# %%
# Task 2: Program eligibility (compound conditions)
print("\nTask 2: Youth Employment Program Eligibility")
print("-" * 45)

person_age = 28
is_employed = False

# YOUR CODE HERE - check if eligible (age 15-35 AND unemployed)
if ____ and ____:
    eligibility = "Eligible"
else:
    eligibility = "Not Eligible"

print(f"Age: {person_age}, Employed: {is_employed}")
print(f"Youth Employment Program: {eligibility}")

# %%
# Task 3: Ternary operator for urban/rural classification
print("\nTask 3: Urban/Rural Classification (Ternary)")
print("-" * 45)

is_urban = True
# YOUR CODE HERE - use ternary operator: "Urban" if is_urban else "Rural"
location_type = ____
print(f"Is Urban: {is_urban} → Location: {location_type}")

is_urban = False
location_type = ____
print(f"Is Urban: {is_urban} → Location: {location_type}")

# %%
# Task 4: Classify multiple ages using list comprehension
print("\nTask 4: Batch Classification with List Comprehension")
print("-" * 50)

ages = [3, 16, 30, 55, 72, 12, 25, 68]

# YOUR CODE HERE - create a list comprehension that classifies each age
# Hint: Use the ternary pattern within the comprehension
# Simplified version: Just classify as "Child" (under 15) or "Adult" (15+)
classifications = [____ for age in ages]

for age, classification in zip(ages, classifications):
    print(f"Age {age:2d} → {classification}")

# %% [markdown]
# **Expected output:**
#
# ```text
# Task 1: Age Group Classification
# -----------------------------------
# Age 42 → Working Age (25-64)
# Age 5 → Child (0-14)
# Age 18 → Youth (15-24)
# Age 42 → Working Age (25-64)
# Age 70 → Elderly (65+)
#
# Task 2: Youth Employment Program Eligibility
# ---------------------------------------------
# Age: 28, Employed: False
# Youth Employment Program: Eligible
#
# Task 3: Urban/Rural Classification (Ternary)
# ---------------------------------------------
# Is Urban: True → Location: Urban
# Is Urban: False → Location: Rural
#
# Task 4: Batch Classification with List Comprehension
# --------------------------------------------------
# Age  3 → Child
# Age 16 → Adult
# Age 30 → Adult
# ...
# ```
