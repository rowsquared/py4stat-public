# %% [markdown]
# # Trade EDA Exercise
#
# This notebook is the **exercise version** (no solutions).
# Use the dataset:
# - `data/trade/0_raw/Trade Data Python Training.xlsx`
#
# Columns expected:
# - `Year`, `Period`, `Flow`, `Partner`, `HScode`, `Description`, `MWKValue`

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
sns.set_theme(style="whitegrid")
pd.set_option("display.max_columns", 50)

# %%
PROJECT_ROOT = os.getcwd()
if not os.path.isdir(os.path.join(PROJECT_ROOT, "data", "trade")):
    PROJECT_ROOT = os.path.dirname(PROJECT_ROOT)

trade_path = Path('../../data/0_raw/malawi/trade data/Trade Data Python Training.xlsx')

df = pd.read_excel(trade_path)
df.columns = [c.strip().lower() for c in df.columns]

df.head()

# %% [markdown]
# ## 1) First diagnostics + univariate EDA
#
# ### Tasks
# 1. Check dtypes and duplicates.
# 2. Define a row key and test duplicate keys.
# 3. Validate:
#    - `flow` in `["I", "E", "RE", "R"]`
#    - `period` in `1..12` (or parse month names)
#    - `mwkvalue` numeric and non-negative
# 4. Create univariate visuals:
#    - histogram and boxplot for `mwkvalue` overall
#    - boxplot by `flow`
#    - top partners and top HS codes by total value
# 5. Build:
#    - EDA summary table (`count`, `min`, `max`, `p50`, `p95`, `p99` for `mwkvalue`)
#    - issue register table with at least 3 findings

# %%
# Exercise 1 workspace
# Write your code below.

# %% [markdown]
# ## 2) Aggregation + pivot tables
#
# ### Tasks
# 1. Create `date = Year-Period-01`.
# 2. Compute imports vs exports per month.
# 3. Compute monthly trade balance (`E - I`) using a flow-to-sign mapping.
# 4. Produce report tables:
#    - partner × flow pivot
#    - HS code × flow pivot (top 10 HS codes)
# 5. Export CSV files:
#    - `trade_by_partner_flow.csv`
#    - `trade_by_hscode_flow.csv`

# %%
# Exercise 2 workspace
# Write your code below.

# %% [markdown]
# ## 3) Bivariate EDA: Seasonality by Flow + Partner Concentration
#
# ### Tasks
# 1. Plot monthly totals (1..12) by flow (aggregated across years).
# 2. Plot monthly totals with one line per year.
# 3. Compute concentration by year for imports and exports:
#    - top 1 partner share
#    - top 3 partner share
#    - top 5 partner share
#    - optional HHI
#
# ### Interpretation prompts
# - Do imports show clear seasonal spikes?
# - Is partner concentration very high in any year?

# %%
# Exercise 3 workspace
# Write your code below.

# %% [markdown]
# ## 4) Visualization clinic (Before/After)
#
# ### Tasks
# A. Exports over time
# - Bad: bar chart with truncated y-axis
# - Fix: line chart and proper axis
#
# B. Partner dominance in exports
# - Bad: pie chart with too many categories
# - Fix: top 10 horizontal bar + "Other"
#
# C. HS code drivers of imports
# - Bad: unsorted vertical bars with long labels
# - Fix: sorted horizontal bars with readable labels

# %%
# Exercise 4 workspace
# Write your code below.

# %% [markdown]
# ## 5) Sankey diagram for trade flows
#
# ### Recommended design
# - Source: `partner`
# - Target: `flow`
# - Value: sum(`mwkvalue`)
#
# ### Tasks
# 1. Filter one year.
# 2. Keep top N partners and group others as `Other`.
# 3. Build Sankey using `plotly.graph_objects`.

# %%
# Exercise 5 workspace
# Write your code below.

# %% [markdown]
# ## 6) Mini-capstone: 1-page briefing
#
# ### Tasks
# Produce:
# 1. 3 headline indicators by year:
#    - total imports
#    - total exports
#    - trade balance
# 2. Top 5 export partners and combined share.
# 3. Top 5 import HS codes.
# 4. 2 visuals:
#    - time series
#    - top partners bar chart
# 5. A short Markdown EDA summary note.

# %%
# Exercise 6 workspace
# Write your code below.
