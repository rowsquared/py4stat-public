# %% [markdown]
# ## Exercise 1.13 - Building Statistical Functions ~20 min
#
# ### Scenario
#
# You've been asked to create a small library of reusable statistical functions for the DNSO team. These functions will be used across multiple projects, so they need to be well-designed with sensible defaults and clear documentation. You'll practice creating functions with required parameters, default values, and flexible argument handling.
#
# ### Dataset
#
# No external dataset needed - you will work with sample numeric lists.
#
# ### Tasks
#
# 1. Create a function `calculate_percentage(part, total)` that returns a percentage value.
# 2. Create a function `classify_district(population, threshold=100000)` with a default parameter to classify districts as "Large" or "Small".
# 3. Create a function `calculate_statistics(values)` that returns multiple values: minimum, maximum, and mean (use tuple unpacking when calling it).
# 4. Create a function `format_population(*values)` using `*args` that accepts any number of population values and returns their sum.
# 5. Create a function `create_record(**attributes)` using `**kwargs` that creates a dictionary record with a timestamp.
# 6. Use a lambda function to sort a list of province dictionaries by population.

# %%
# Exercise 1.13 - Building Statistical Functions
# Datania National Statistics Office

# Task 1: Create a basic percentage function
def calculate_percentage(part, total):
    """Calculate percentage of part relative to total."""
    # YOUR CODE HERE
    pass

# Test Task 1
print("Task 1: Basic Percentage Function")
print("-" * 40)
urban_pop = 7955000
total_pop = 18500000
result = calculate_percentage(urban_pop, total_pop)
print(f"Urbanization rate: {result:.1f}%")

# %%
# Task 2: Function with default parameter
def classify_district(population, threshold=100000):
    """
    Classify district based on population size.

    Parameters:
        population: District population count
        threshold: Cutoff for large/small classification (default: 100,000)

    Returns:
        str: "Large" or "Small"
    """
    # YOUR CODE HERE
    pass

# Test Task 2
print("\nTask 2: Function with Default Parameter")
print("-" * 45)
print(f"Population 150,000: {classify_district(150000)}")
print(f"Population 50,000: {classify_district(50000)}")
print(f"Population 50,000 (threshold 40,000): {classify_district(50000, threshold=40000)}")

# %%
# Task 3: Function returning multiple values
def calculate_statistics(values):
    """
    Calculate basic statistics for a list of values.

    Returns:
        tuple: (minimum, maximum, mean)
    """
    # YOUR CODE HERE - return min, max, and mean as a tuple
    pass

# Test Task 3
print("\nTask 3: Multiple Return Values")
print("-" * 40)
populations = [5200000, 3800000, 2100000, 1900000, 2500000, 3000000]
# YOUR CODE HERE - unpack the returned tuple
minimum, maximum, mean = ____
print(f"Min: {minimum:,}")
print(f"Max: {maximum:,}")
print(f"Mean: {mean:,.0f}")

# %%
# Task 4: Function with *args (variable arguments)
def format_population(*values):
    """
    Accept any number of population values and return their total.

    Example: format_population(100, 200, 300) returns 600
    """
    # YOUR CODE HERE
    pass

# Test Task 4
print("\nTask 4: Variable Arguments (*args)")
print("-" * 40)
total = format_population(5200000, 3800000, 2100000)
print(f"Total of 3 provinces: {total:,}")

total = format_population(5200000, 3800000, 2100000, 1900000, 2500000, 3000000)
print(f"Total of 6 provinces: {total:,}")

# %%
# Task 5: Function with **kwargs (keyword arguments)
def create_record(**attributes):
    """
    Create a data record with a timestamp and any additional attributes.

    Returns:
        dict: Record with timestamp and all provided attributes
    """
    from datetime import datetime
    record = {"created_at": datetime.now().strftime("%Y-%m-%d %H:%M")}
    # YOUR CODE HERE - add all attributes to the record

    return record

# Test Task 5
print("\nTask 5: Keyword Arguments (**kwargs)")
print("-" * 45)
household = create_record(
    household_id="HH001",
    district="Numerica",
    members=5,
    income=45000
)
print("Created record:")
for key, value in household.items():
    print(f"  {key}: {value}")

# %%
# Task 6: Lambda function for sorting
print("\nTask 6: Lambda Function for Sorting")
print("-" * 40)
provinces = [
    {"name": "Central", "population": 5200000},
    {"name": "Southern", "population": 3800000},
    {"name": "Northern", "population": 2100000},
    {"name": "Lakeside", "population": 3000000}
]

# YOUR CODE HERE - sort by population using lambda
sorted_provinces = sorted(provinces, key=____)

print("Provinces by population (ascending):")
for p in sorted_provinces:
    print(f"  {p['name']}: {p['population']:,}")

# %%
# ==========================================
# EXTRA CHALLENGE: Combine concepts
# ==========================================
print("\n" + "=" * 50)
print("EXTRA CHALLENGE: Flexible Statistics Function")
print("=" * 50)

def analyze_data(data, stat_type="mean", precision=2):
    """
    Calculate various statistics with configurable output.

    Parameters:
        data: List of numeric values
        stat_type: Type of statistic - "mean", "sum", "count", or "range"
        precision: Number of decimal places for output

    Returns:
        Formatted string with the result
    """
    # YOUR CODE HERE - implement different stats based on stat_type
    # Use match-case if you know Python 3.10+, otherwise use if-elif
    pass

# Test the challenge
test_data = [45000, 32000, 78000, 55000, 41000]
print(f"Data: {test_data}")
print(f"Mean: {analyze_data(test_data, 'mean')}")
print(f"Sum: {analyze_data(test_data, 'sum')}")
print(f"Count: {analyze_data(test_data, 'count')}")
print(f"Range: {analyze_data(test_data, 'range')}")

# %% [markdown]
# **Expected output:**
#
# ```text
# Task 1: Basic Percentage Function
# ----------------------------------------
# Urbanization rate: 43.0%
#
# Task 2: Function with Default Parameter
# ---------------------------------------------
# Population 150,000: Large
# Population 50,000: Small
# Population 50,000 (threshold 40,000): Large
#
# Task 3: Multiple Return Values
# ----------------------------------------
# Min: 1,900,000
# Max: 5,200,000
# Mean: 3,083,333
#
# Task 4: Variable Arguments (*args)
# ----------------------------------------
# Total of 3 provinces: 11,100,000
# Total of 6 provinces: 18,500,000
#
# Task 5: Keyword Arguments (**kwargs)
# ---------------------------------------------
# Created record:
#   created_at: 2026-03-15 23:00
#   household_id: HH001
#   district: Numerica
#   members: 5
#   income: 45000
#
# Task 6: Lambda Function for Sorting
# ----------------------------------------
# Provinces by population (ascending):
#   Northern: 2,100,000
#   Lakeside: 3,000,000
#   Southern: 3,800,000
#   Central: 5,200,000
#
# ==================================================
# EXTRA CHALLENGE: Flexible Statistics Function
# ==================================================
# Data: [45000, 32000, 78000, 55000, 41000]
# Mean: 50200.00
# Sum: 251000.00
# Count: 5
# Range: 46000.00
# ```
