# %% [markdown]
# # Exercise 1.8-1.9: District Data Processing
# *Exercício 1.8-1.9: Processamento de Dados dos Distritos*
#
# You will practice:
# - List methods: `append()`
# - `for` loops with `enumerate()` and `zip()`
# - List comprehensions with conditions
# - `while` loops
# - `range()` for generating sequences
#
# *Vai praticar:*
# - *Métodos de listas: `append()`*
# - *Ciclos `for` com `enumerate()` e `zip()`*
# - *Compreensões de lista com condições*
# - *Ciclos `while`*
# - *`range()` para gerar sequências*

# %%
# Starting data | Dados iniciais
districts = ["Numerica Urban", "Median Urban", "Polaris District", "Outlier Coastal", "Deviation District"]
target_samples = [500, 450, 300, 350, 280]

# %% [markdown]
# ---
#
# ## Task 1: Add a new district
# *Tarefa 1: Acrescentar um novo distrito*
#
# Append `"Port Sample"` to `districts` and `320` to `target_samples`.
#
# *Acrescente `"Port Sample"` a `districts` e `320` a `target_samples`.*

# %%
# Task 1: append new district | Tarefa 1: acrescentar o novo distrito
print("Task 1: Adding New District")
print("-" * 35)
districts.# your code here | o seu código aqui
target_samples.# your code here | o seu código aqui
print(f"Districts: {districts}")
print(f"Targets:   {target_samples}")

# %% [markdown]
# ---
#
# ## Task 2: Print a numbered list with `enumerate()`
# *Tarefa 2: Imprimir uma lista numerada com `enumerate()`*
#
# Use `enumerate(districts, start=1)` to print `"1. Numerica Urban"`, `"2. Median Urban"`, etc.
#
# *Use `enumerate(districts, start=1)` para imprimir `"1. Numerica Urban"`, `"2. Median Urban"`, etc.*

# %%
# Task 2: enumerate | Tarefa 2: enumerate
print("\nTask 2: Numbered District List")
print("-" * 35)
# your code here | o seu código aqui
for # your code here in enumerate(districts, start=1):
    print(f"# your code here. # your code here")

# %% [markdown]
# ---
#
# ## Task 3: Total sample size with `zip()`
# *Tarefa 3: Dimensão total da amostra com `zip()`*
#
# Loop through `districts` and `target_samples` together with `zip()`. Accumulate the total.
#
# *Percorra `districts` e `target_samples` em conjunto com `zip()`. Acumule o total.*

# %%
# Task 3: zip | Tarefa 3: zip
print("\nTask 3: Total Sample Size")
print("-" * 40)
total_sample = 0
# your code here, twice | o seu código aqui, duas vezes
for district, target in zip(# your code here, # your code here):
    print(f"  {district}: {target}")
    total_sample += target
print(f"\nTotal target sample: {total_sample}")

# %% [markdown]
# ---
#
# ## Task 4: Filter with a list comprehension
# *Tarefa 4: Filtrar com uma compreensão de lista*
#
# Create a list of `(district, target)` tuples where `target > 300`.
#
# *Crie uma lista de tuplos `(district, target)` em que `target > 300`.*

# %%
# Task 4: list comprehension | Tarefa 4: compreensão de lista
print("\nTask 4: Districts with Target > 300")
print("-" * 40)
# your code here, before the `for` | o seu código aqui, antes do `for`
large_districts = [# your code here for district, target in zip(districts, target_samples) if target > 300]
print("Large districts (target > 300):")
for item in large_districts:
    print(f"  {item}")

# %% [markdown]
# ---
#
# ## Task 5: Simulate data collection with a `while` loop
# *Tarefa 5: Simular a recolha de dados com um ciclo `while`*
#
# Collect 20 responses per day until `target = 100` is reached. Print each day's progress.
#
# *Recolha 20 respostas por dia até atingir `target = 100`. Imprima o progresso de cada dia.*

# %%
# Task 5: while loop simulation | Tarefa 5: simulação com ciclo while
print("\nTask 5: Data Collection Simulation")
print("-" * 40)
collected = 0
target = 100
day = 0

# continue while collected < target | continuar enquanto collected < target
while # your code here:
    day += 1
    daily_collection = 20
    collected += daily_collection
    print(f"Day {day}: Collected {daily_collection}, Total: {collected}")
    if collected >= target:
        print(f"\nTarget of {target} reached in {day} days!")
        break

# %% [markdown]
# ---
#
# ## Task 6: Generate census years with `range()`
# *Tarefa 6: Gerar os anos censitários com `range()`*
#
# Create a list of years from 1960 to 2020 (inclusive), stepping by 10.
#
# *Crie uma lista de anos de 1960 a 2020 (inclusive), com um passo de 10.*

# %%
# Task 6: range | Tarefa 6: range
print("\nTask 6: Census Years")
print("-" * 25)
census_years = list(range(# your code here | o seu código aqui))
print(f"Datania Census Years: {census_years}")

# %% [markdown]
# **Expected output:**
#
# ***Resultado esperado:***
#
# ```text
# Task 1: Adding New District
# -----------------------------------
# Districts: ['Numerica Urban', 'Median Urban', 'Polaris District', 'Outlier Coastal', 'Deviation District', 'Port Sample']
# Targets:   [500, 450, 300, 350, 280, 320]
#
# Task 2: Numbered District List
# -----------------------------------
# 1. Numerica Urban
# 2. Median Urban
# ...
#
# Task 3: Total Sample Size
# ----------------------------------------
#   Numerica Urban: 500
#   ...
# Total target sample: 2200
#
# Task 4: Districts with Target > 300
# ----------------------------------------
# Large districts (target > 300):
#   ('Numerica Urban', 500)
#   ...
#
# Task 5: Data Collection Simulation
# ----------------------------------------
# Day 1: Collected 20, Total: 20
# ...
# Target of 100 reached in 5 days!
#
# Task 6: Census Years
# -------------------------
# Datania Census Years: [1960, 1970, 1980, 1990, 2000, 2010, 2020]
# ```
