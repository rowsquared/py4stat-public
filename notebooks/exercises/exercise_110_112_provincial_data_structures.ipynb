# %% [markdown]
# # Exercise 1.10–1.12 — Provincial Data Structures
#
# You are preparing data for the Datania Statistical Yearbook. You need to organise provincial data using appropriate data structures.
#
# You will practice:
# - **Tuples** for immutable reference data
# - **Dictionaries** for structured records and nested lookups
# - **Sets** for deduplication and comparison

# %% [markdown]
# ---
#
# ## Part 1 — Tuples
#
# ## Task 1 — Create a tuple of province codes
#
# Create an immutable tuple with these codes: `NTH, STH, EST, WST, CTR, LKS`.

# %%
# Task 1 — province codes tuple
print("PART 1: TUPLES")
print("=" * 40)

province_codes = (# your code here)
print(f"Province codes: {province_codes}")

# Uncomment to see what happens when you try to modify a tuple:
# province_codes[0] = "NEW"

# %% [markdown]
# ---
#
# ## Task 2 — Unpack GPS coordinates
#
# Unpack `numerica_coords` into two variables: `latitude` and `longitude`.

# %%
# Task 2 — tuple unpacking
numerica_coords = (-15.4167, 28.2833)
# your code here — unpack into latitude, longitude
print(f"\nNumerica coordinates:")
print(f"  Latitude:  {latitude}")
print(f"  Longitude: {longitude}")

# %% [markdown]
# ---
#
# ## Part 2 — Dictionaries
#
# ## Task 3 — Create and update a dictionary
#
# Create a dictionary for Central Province with keys `name`, `capital`, `population`, `area_km2`. Then update the population to `5 350 000`.

# %%
# Task 3 — dictionary
print("\nPART 2: DICTIONARIES")
print("=" * 45)

central_province = {
    "name": # your code here,
    "capital": # your code here,
    "population": # your code here,
    "area_km2": 21896
}

print(f"Province:  {central_province['name']}")
print(f"Capital:   {central_province['capital']}")
print(f"Population: {central_province['population']:,}")

# Update population
central_province[# your code here] = 5350000
print(f"Updated population: {central_province['population']:,}")

# Safe access for a key that might not exist
gdp = central_province.get("gdp", "Not available")
print(f"GDP: {gdp}")

# %% [markdown]
# ---
#
# ## Task 4 — Access a nested dictionary
#
# Access the `urban_rate` of Southern Province from `province_data`.

# %%
# Task 4 — nested dictionary
print("\nNested Dictionary:")
print("-" * 30)
province_data = {
    "CTR": {"name": "Central",  "population": 5200000, "urban_rate": 0.75},
    "STH": {"name": "Southern", "population": 3800000, "urban_rate": 0.60},
    "NTH": {"name": "Northern", "population": 2100000, "urban_rate": 0.30},
}

southern_urban_rate = province_data[# your code here][# your code here]
print(f"Southern Province urban rate: {southern_urban_rate:.0%}")

for code, data in province_data.items():
    print(f"{code}: {data['name']} — Pop: {data['population']:,}")

# %% [markdown]
# ---
#
# ## Part 3 — Sets
#
# ## Task 5 — Find unique occupations
#
# Convert `responses` to a set to deduplicate it.

# %%
# Task 5 — sets
print("\nPART 3: SETS")
print("=" * 50)

responses = ["Farmer", "Teacher", "Farmer", "Nurse", "Teacher", "Farmer", "Driver", "Nurse"]
print(f"Raw responses ({len(responses)} total): {responses}")

unique_occupations = # your code here — convert to set
print(f"Unique occupations ({len(unique_occupations)}): {unique_occupations}")

# %% [markdown]
# ---
#
# ## Task 6 — Compare survey rounds with set operations
#
# Use set operators to find:
# - **Panel households** — in both rounds (`&`)
# - **Dropped households** — only in round 1 (`-`)
# - **New households** — only in round 2 (`-`)
# - **All unique households** — union (`|`)

# %%
# Task 6 — set comparisons
print("\nComparing Survey Rounds:")
print("-" * 35)
round_1 = {"HH001", "HH002", "HH003", "HH004", "HH005"}
round_2 = {"HH003", "HH004", "HH005", "HH006", "HH007"}
print(f"Round 1: {round_1}")
print(f"Round 2: {round_2}")

panel    = round_1 # your code here round_2   # intersection
dropped  = round_1 # your code here round_2   # only in round 1
new      = round_2 # your code here round_1   # only in round 2
all_hh   = round_1 # your code here round_2   # union

print(f"\nPanel (both):        {panel}")
print(f"Dropped (round 1 only): {dropped}")
print(f"New (round 2 only):  {new}")
print(f"All unique:          {all_hh}")

# %% [markdown]
# **Expected output:**
#
# ```text
# PART 1: TUPLES
# ========================================
# Province codes: ('NTH', 'STH', 'EST', 'WST', 'CTR', 'LKS')
#
# Numerica coordinates:
#   Latitude:  -15.4167
#   Longitude: 28.2833
#
# PART 2: DICTIONARIES
# =============================================
# Province:  Central
# Capital:   Numerica
# Population: 5,200,000
# Updated population: 5,350,000
# GDP: Not available
#
# Nested Dictionary:
# ------------------------------
# Southern Province urban rate: 60%
# ...
#
# PART 3: SETS
# ==================================================
# Raw responses (8 total): [...]
# Unique occupations (4): {'Farmer', 'Teacher', 'Nurse', 'Driver'}
#
# Comparing Survey Rounds:
# -----------------------------------
# Panel (both):           {'HH003', 'HH004', 'HH005'}
# Dropped (round 1 only): {'HH001', 'HH002'}
# New (round 2 only):     {'HH006', 'HH007'}
# All unique:             {'HH001', ..., 'HH007'}
# ```
