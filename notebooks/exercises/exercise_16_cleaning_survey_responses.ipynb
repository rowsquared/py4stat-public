# %% [markdown]
# # Exercise 1.6: Cleaning Survey Responses
# *Exercício 1.6: Limpeza de Respostas de Inquérito*
#
# You will practice:
# - `strip()`, `title()`, `lower()`, `upper()`
# - `join()` and `split()`
# - `in` operator for keyword search
# - `replace()`
#
# *Vai praticar:*
# - *`strip()`, `title()`, `lower()`, `upper()`*
# - *`join()` e `split()`*
# - *o operador `in` para procurar palavras-chave*
# - *`replace()`*

# %%
# Raw occupation data from field enumerators
# Dados brutos de profissões recolhidos pelos inquiridores no terreno
raw_occupations = [
    "  subsistence FARMER  ",
    "TEACHER, secondary school",
    "  Government clerk",
    "small business OWNER  ",
    "Domestic worker "
]

# %% [markdown]
# ---
#
# ## Task 1: Clean each occupation string
# *Tarefa 1: Limpar cada texto de profissão*
#
# For each entry: remove leading/trailing whitespace and convert to title case.
#
# *Para cada entrada: remova os espaços no início e no fim e converta para maiúsculas iniciais (title case).*

# %%
# Task 1: clean occupations | Tarefa 1: limpar as profissões
print("Task 1: Cleaned Occupations")
print("-" * 30)
for occupation in raw_occupations:
    cleaned = # your code here: strip and title-case the string
              # o seu código aqui: retirar espaços e aplicar maiúsculas iniciais
    print(cleaned)

# %% [markdown]
# ---
#
# ## Task 2: Build a formatted address
# *Tarefa 2: Construir um endereço formatado*
#
# Join these parts with `", "`: `["Plot 45", "Main Street", "Numerica", "Central Province"]`
#
# *Junte estas partes com `", "`: `["Plot 45", "Main Street", "Numerica", "Central Province"]`*

# %%
# Task 2: formatted address | Tarefa 2: endereço formatado
print("\nTask 2: Formatted Address")
print("-" * 30)
address_parts = ["Plot 45", "Main Street", "Numerica", "Central Province"]
full_address = # your code here: join with ", " | o seu código aqui: juntar com ", "
print(full_address)

# %% [markdown]
# ---
#
# ## Task 3: Extract province code from an EA code
# *Tarefa 3: Extrair o código da província a partir de um código de AE*
#
# EA code: `"CTR-NUM-042"`. Split on `"-"` and take the first part.
#
# *Código da área de enumeração (AE): `"CTR-NUM-042"`. Divida em `"-"` e fique com a primeira parte.*

# %%
# Task 3: extract province code | Tarefa 3: extrair o código da província
print("\nTask 3: Province Code Extraction")
print("-" * 30)
ea_code = "CTR-NUM-042"
province_code = # your code here | o seu código aqui
print(f"EA Code: {ea_code}")
print(f"Province Code: {province_code}")

# %% [markdown]
# ---
#
# ## Task 4: Case-insensitive keyword search
# *Tarefa 4: Procura de palavra-chave sem distinguir maiúsculas de minúsculas*
#
# Check if `"Subsistence Farmer"` contains the word `"farmer"` (case-insensitive).
#
# *Verifique se `"Subsistence Farmer"` contém a palavra `"farmer"` (ignorando maiúsculas e minúsculas).*

# %%
# Task 4: keyword search | Tarefa 4: procura de palavra-chave
print("\nTask 4: Keyword Search")
print("-" * 30)
occupation_to_check = "Subsistence Farmer"
is_farmer = # your code here: True if "farmer" appears (use .lower())
            # o seu código aqui: True se "farmer" aparecer (use .lower())
print(f"Occupation: {occupation_to_check}")
print(f"Contains 'farmer': {is_farmer}")

# %% [markdown]
# ---
#
# ## Task 5: Replace text
# *Tarefa 5: Substituir texto*
#
# In the string `"Government clerk at Government office"`, replace every occurrence of `"Government"` with `"Public Sector"`.
#
# *No texto `"Government clerk at Government office"`, substitua todas as ocorrências de `"Government"` por `"Public Sector"`.*

# %%
# Task 5: text replacement | Tarefa 5: substituição de texto
print("\nTask 5: Text Replacement")
print("-" * 30)
original_text = "Government clerk at Government office"
updated_text = # your code here | o seu código aqui
print(f"Original: {original_text}")
print(f"Updated:  {updated_text}")

# %% [markdown]
# **Expected output:**
#
# ***Resultado esperado:***
#
# ```text
# Task 1: Cleaned Occupations
# ------------------------------
# Subsistence Farmer
# Teacher, Secondary School
# Government Clerk
# Small Business Owner
# Domestic Worker
#
# Task 2: Formatted Address
# ------------------------------
# Plot 45, Main Street, Numerica, Central Province
#
# Task 3: Province Code Extraction
# ------------------------------
# EA Code: CTR-NUM-042
# Province Code: CTR
#
# Task 4: Keyword Search
# ------------------------------
# Occupation: Subsistence Farmer
# Contains 'farmer': True
#
# Task 5: Text Replacement
# ------------------------------
# Original: Government clerk at Government office
# Updated:  Public Sector clerk at Public Sector office
# ```
