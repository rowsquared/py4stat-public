# %% [markdown]
# # Exercise 1.7: Age Group Classifier
# *Exercício 1.7: Classificador de Grupos Etários*
#
# You will practice:
# - `if / elif / else` branching
# - Compound boolean conditions (`and`, `or`, `not`)
# - Ternary (inline) expressions
# - List comprehensions with conditions
#
# *Vai praticar:*
# - *Ramificação com `if / elif / else`*
# - *Condições booleanas compostas (`and`, `or`, `not`)*
# - *Expressões ternárias (em linha)*
# - *Compreensões de lista com condições*

# %% [markdown]
# ---
#
# ## Task 1: Classify a single age into age groups
# *Tarefa 1: Classificar uma idade num grupo etário*
#
# Write an `if / elif / else` block that assigns one of these labels:
#
# *Escreva um bloco `if / elif / else` que atribua um destes rótulos:*
#
# | Age range / Intervalo de idades | Label / Rótulo |
# |---|---|
# | 0-14 | `"Child (0-14)"` |
# | 15-24 | `"Youth (15-24)"` |
# | 25-64 | `"Working Age (25-64)"` |
# | 65+ | `"Elderly (65+)"` |
#
# Then loop over `test_ages` using the same logic.
#
# *Depois, percorra `test_ages` com a mesma lógica.*

# %%
# Task 1: classify a single age | Tarefa 1: classificar uma única idade
print("Task 1: Age Group Classification")
print("-" * 35)

age = 42  # change this value to test other cases | altere este valor para testar outros casos

if # your code here | o seu código aqui:
    age_group = "Child (0-14)"
elif # your code here | o seu código aqui:
    age_group = "Youth (15-24)"
elif # your code here | o seu código aqui:
    age_group = "Working Age (25-64)"
else:
    age_group = "Elderly (65+)"

print(f"Age {age} → {age_group}")

# %%
# Task 1 (continued): classify a list of ages
# Tarefa 1 (continuação): classificar uma lista de idades
test_ages = [5, 18, 42, 70]
for test_age in test_ages:
    # your code here: copy the if/elif/else and replace age with test_age
    # o seu código aqui: copie o if/elif/else e substitua age por test_age
    pass

# %% [markdown]
# ---
#
# ## Task 2: Compound condition: programme eligibility
# *Tarefa 2: Condição composta: elegibilidade para o programa*
#
# A person is eligible for the **Youth Employment Programme** if:
# - Age is between 15 and 35 (inclusive), **AND**
# - They are currently unemployed (`is_employed = False`)
#
# *Uma pessoa é elegível para o **Programa de Emprego Jovem** se:*
# - *A idade estiver entre 15 e 35 anos (inclusive), **E***
# - *Estiver atualmente desempregada (`is_employed = False`)*

# %%
# Task 2: programme eligibility | Tarefa 2: elegibilidade para o programa
print("\nTask 2: Youth Employment Programme Eligibility")
print("-" * 45)

person_age = 28
is_employed = False

# o seu código aqui (condição de idade) e o seu código aqui (condição de emprego)
if # your code here (age condition) and # your code here (employment condition):
    eligibility = "Eligible"
else:
    eligibility = "Not Eligible"

print(f"Age: {person_age}, Employed: {is_employed}")
print(f"Youth Employment Programme: {eligibility}")

# %% [markdown]
# ---
#
# ## Task 3: Ternary expression for urban/rural
# *Tarefa 3: Expressão ternária para urbano/rural*
#
# Assign `"Urban"` or `"Rural"` in a single line using a ternary expression:
#
# *Atribua `"Urban"` ou `"Rural"` numa única linha, usando uma expressão ternária:*
#
# ```python
# value = "Urban" if is_urban else "Rural"
# ```

# %%
# Task 3: ternary expression | Tarefa 3: expressão ternária
print("\nTask 3: Urban/Rural Classification (Ternary)")
print("-" * 45)

is_urban = True
location_type = # your code here | o seu código aqui
print(f"Is Urban: {is_urban} → Location: {location_type}")

is_urban = False
location_type = # your code here | o seu código aqui
print(f"Is Urban: {is_urban} → Location: {location_type}")

# %% [markdown]
# ---
#
# ## Task 4: Batch classification with a list comprehension
# *Tarefa 4: Classificação em lote com uma compreensão de lista*
#
# Classify each age in `ages` as `"Child"` (under 15) or `"Adult"` (15+) using a list comprehension with a ternary expression.
#
# *Classifique cada idade em `ages` como `"Child"` (menos de 15) ou `"Adult"` (15 ou mais), usando uma compreensão de lista com uma expressão ternária.*

# %%
# Task 4: list comprehension | Tarefa 4: compreensão de lista
print("\nTask 4: Batch Classification with List Comprehension")
print("-" * 50)

ages = [3, 16, 30, 55, 72, 12, 25, 68]
# your code here for age in ages | o seu código aqui for age in ages
classifications = [# your code here for age in ages]

for age, cls in zip(ages, classifications):
    print(f"Age {age:2d} → {cls}")

# %% [markdown]
# **Expected output:**
#
# ***Resultado esperado:***
#
# ```text
# Task 1: Age Group Classification
# -----------------------------------
# Age 42 → Working Age (25-64)
# Age 5 → Child (0-14)
# Age 18 → Youth (15-24)
# Age 42 → Working Age (25-64)
# Age 70 → Elderly (65+)
#
# Task 2: Youth Employment Programme Eligibility
# ---------------------------------------------
# Age: 28, Employed: False
# Youth Employment Programme: Eligible
#
# Task 3: Urban/Rural Classification (Ternary)
# ---------------------------------------------
# Is Urban: True → Location: Urban
# Is Urban: False → Location: Rural
#
# Task 4: Batch Classification with List Comprehension
# --------------------------------------------------
# Age  3 → Child
# Age 16 → Adult
# ...
# ```
