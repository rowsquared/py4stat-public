# %% [markdown]
# # Exercise 1.5: Population Statistics Calculator
# *Exercício 1.5: Calculadora de Estatísticas Populacionais*
#
# You will practice:
# - Assigning values to variables with descriptive `snake_case` names
# - Performing arithmetic calculations
# - Formatting output with f-strings
# - Checking data types with `type()`
#
# *Vai praticar:*
# - *Atribuir valores a variáveis com nomes descritivos em `snake_case`*
# - *Realizar cálculos aritméticos*
# - *Formatar resultados com f-strings*
# - *Verificar tipos de dados com `type()`*
#
# **No external dataset needed**: all values are provided below.
#
# ***Não é necessário nenhum conjunto de dados externo:** todos os valores são fornecidos a seguir.*

# %% [markdown]
# ---
#
# ## Task 1: Create variables for population data
# *Tarefa 1: Criar variáveis para os dados populacionais*
#
# Store each value in a variable. Use the names below exactly:
#
# *Guarde cada valor numa variável. Use exatamente os nomes indicados a seguir:*
#
# | Variable / Variável | Value / Valor |
# |---|---|
# | `total_population` | 18 500 000 |
# | `urban_population` | 7 955 000 |
# | `rural_population` | 10 545 000 |
# | `census_year` | 2020 |
# | `growth_rate` | 0.0287 (i.e. 2.87 % / ou seja, 2,87 %) |

# %%
# Task 1: population variables | Tarefa 1: variáveis de população
total_population = # your code here | o seu código aqui
urban_population = # your code here | o seu código aqui
rural_population = # your code here | o seu código aqui
census_year = # your code here | o seu código aqui
growth_rate = # your code here (store as decimal, e.g. 2.87 % -> 0.0287)
              # o seu código aqui (guarde como decimal, por ex. 2,87 % -> 0.0287)

# %% [markdown]
# ---
#
# ## Task 2: Calculate the urbanisation rate
# *Tarefa 2: Calcular a taxa de urbanização*
#
# Urbanisation rate = urban population / total population.
#
# *Taxa de urbanização = população urbana / população total.*

# %%
# Task 2: urbanisation rate | Tarefa 2: taxa de urbanização
urbanisation_rate = # your code here | o seu código aqui

# %% [markdown]
# ---
#
# ## Task 3: Project the population to 2025
# *Tarefa 3: Projetar a população para 2025*
#
# Use the compound growth formula:
# `projected = current × (1 + growth_rate) ** years`
#
# *Use a fórmula de crescimento composto:*
# *`projetada = atual × (1 + taxa_de_crescimento) ** anos`*

# %%
# Task 3: projected population for 2025 | Tarefa 3: população projetada para 2025
years_ahead = 2025 - census_year
projected_population_2025 = # your code here | o seu código aqui

# %% [markdown]
# ---
#
# ## Task 4: Print a formatted summary
# *Tarefa 4: Imprimir um resumo formatado*
#
# Use f-strings. Format the urbanisation rate as a percentage with one decimal place (`:.1%` or `:.1f` after multiplying by 100).
#
# *Use f-strings. Formate a taxa de urbanização como percentagem com uma casa decimal (`:.1%` ou `:.1f` depois de multiplicar por 100).*

# %%
# Task 4: print results | Tarefa 4: imprimir resultados
print(f"Datania Population Statistics ({census_year} Census)")
print("=" * 45)
# your code here: print total_population | o seu código aqui: imprimir total_population
# your code here: print urban_population | o seu código aqui: imprimir urban_population
# your code here: print rural_population | o seu código aqui: imprimir rural_population
# your code here: print urbanisation_rate as percentage
# o seu código aqui: imprimir urbanisation_rate em percentagem
# your code here: print projected_population_2025
# o seu código aqui: imprimir projected_population_2025

# %% [markdown]
# ---
#
# ## Task 5: Check data types
# *Tarefa 5: Verificar os tipos de dados*
#
# Use `type()` to verify and print the data type of at least two variables.
#
# *Use `type()` para verificar e imprimir o tipo de dados de pelo menos duas variáveis.*

# %%
# Task 5: verify types | Tarefa 5: verificar os tipos
print("\nData Type Verification:")
# your code here, e.g. print(f"total_population: {type(total_population)}")
# o seu código aqui, por ex. print(f"total_population: {type(total_population)}")

# %% [markdown]
# **Expected output (approximate):**
#
# ***Resultado esperado (aproximado):***
#
# ```text
# Datania Population Statistics (2020 Census)
# =============================================
# Total Population:  18,500,000
# Urban Population:   7,955,000
# Rural Population:  10,545,000
# Urbanisation Rate:     43.0%
# Projected (2025):  21,315,XXX
#
# Data Type Verification:
# total_population: <class 'int'>
# growth_rate: <class 'float'>
# ```
