# %% [markdown]
# ## Exercise 1.6 - Cleaning Survey Responses ~15 min
#
# ### Scenario
#
# Grace Tembo from the DNSO Data Quality team has sent you a batch of occupation descriptions from the recent Labour Force Survey. The data entry was done by multiple enumerators and the text is inconsistent - some responses have extra spaces, inconsistent capitalization, and need to be standardized. Your task is to clean these text responses using Python string methods.
#
# ### Dataset
#
# No external dataset needed - you will work with the following raw occupation entries:

# %%
raw_occupations = [
    "  subsistence FARMER  ",
    "TEACHER, secondary school",
    "  Government clerk",
    "small business OWNER  ",
    "Domestic worker "
]

# %% [markdown]
# ### Tasks
#
# 1. Clean each occupation string by removing leading/trailing whitespace and converting to title case.
# 2. Create a formatted address string by joining these parts: "Plot 45", "Main Street", "Numerica", "Central Province" - separated by commas and spaces.
# 3. Extract the province code from the EA code `"CTR-NUM-042"` (hint: use `split()`).
# 4. Check if a given occupation description contains the word "farmer" (case-insensitive check).
# 5. Replace all occurrences of "Government" with "Public Sector" in the string `"Government clerk at Government office"`.

# %%
# Exercise 1.6 - Cleaning Survey Responses
# Datania National Statistics Office

# Raw occupation data from field enumerators
raw_occupations = [
    "  subsistence FARMER  ",
    "TEACHER, secondary school",
    "  Government clerk",
    "small business OWNER  ",
    "Domestic worker "
]

# Task 1: Clean each occupation (remove whitespace, convert to title case)
print("Task 1: Cleaned Occupations")
print("-" * 30)
for occupation in raw_occupations:
    # YOUR CODE HERE - clean and print each occupation
    cleaned = ____
    print(cleaned)

# %%
# Task 2: Create formatted address from parts
print("\nTask 2: Formatted Address")
print("-" * 30)
address_parts = ["Plot 45", "Main Street", "Numerica", "Central Province"]
# YOUR CODE HERE - join the parts with ", "
full_address = ____
print(full_address)

# %%
# Task 3: Extract province code from EA code
print("\nTask 3: Province Code Extraction")
print("-" * 30)
ea_code = "CTR-NUM-042"
# YOUR CODE HERE - split the code and get the first part
province_code = ____
print(f"EA Code: {ea_code}")
print(f"Province Code: {province_code}")

# %%
# Task 4: Check if occupation contains "farmer" (case-insensitive)
print("\nTask 4: Keyword Search")
print("-" * 30)
occupation_to_check = "Subsistence Farmer"
# YOUR CODE HERE - check if "farmer" is in the occupation (convert to lower first)
is_farmer = ____
print(f"Occupation: {occupation_to_check}")
print(f"Contains 'farmer': {is_farmer}")

# %%
# Task 5: Replace text in string
print("\nTask 5: Text Replacement")
print("-" * 30)
original_text = "Government clerk at Government office"
# YOUR CODE HERE - replace "Government" with "Public Sector"
updated_text = ____
print(f"Original: {original_text}")
print(f"Updated: {updated_text}")

# %% [markdown]
# **Expected output:**
#
# ```text
# Task 1: Cleaned Occupations
# ------------------------------
# Subsistence Farmer
# Teacher, Secondary School
# Government Clerk
# Small Business Owner
# Domestic Worker
#
# Task 2: Formatted Address
# ------------------------------
# Plot 45, Main Street, Numerica, Central Province
#
# Task 3: Province Code Extraction
# ------------------------------
# EA Code: CTR-NUM-042
# Province Code: CTR
#
# Task 4: Keyword Search
# ------------------------------
# Occupation: Subsistence Farmer
# Contains 'farmer': True
#
# Task 5: Text Replacement
# ------------------------------
# Original: Government clerk at Government office
# Updated: Public Sector clerk at Public Sector office
# ```
