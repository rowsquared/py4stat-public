# %% [markdown]
# # Trade Exercise: Feature Engineering for Analysis-Ready Data
#
# Use the Malawi trade dataset in:
# - `data/trade/0_raw/Trade Data Python Training.xlsx`
#
# Goals:
# 1. Add USD conversion by year.
# 2. Build time features (`date`, `quarter`, `month_name`).
# 3. Add signed trade values for balance calculations.
# 4. Add placeholder unit-value logic (requires quantity).
# 5. Create HS hierarchy features (`HS2`, `HS4`).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path


trade_path = Path('../../data/0_raw/malawi/trade data/Trade Data Python Training.xlsx')
df = pd.read_excel(trade_path)

df.head()

# %% [markdown]
# ## A) Add USD conversion with monthly exchange rates (2024)
#
# Create this FX table:
#
# ```python
# fx = pd.DataFrame({
#     "Year": [2024] * 12,
#     "Period": list(range(1, 13)),
#     "MWK_per_USD": [1700, 1710, 1720, 1730, 1740, 1750, 1760, 1770, 1780, 1790, 1800, 1810]
# })
# ```
#
# Then merge on `Year` + `Period` and create `USDValue`.

# %%
# Exercise A workspace
# Write your code below.

# %%
# Exercise A (stretch) workspace
# Write your code below.

# %% [markdown]
# ## B) Create proper date + quarter + month name
#
# From `Year` and `Period`, create:
# - `date`
# - `quarter`
# - `month_name`

# %%
# Exercise B workspace
# Write your code below.

# %% [markdown]
# ## C) Add signed values by flow type
#
# Mapping convention:
# - `I` -> `-1`
# - `E` -> `+1`
# - `RE` -> `+1`
# - `R` -> `-1`
#
# Create:
# - `flow_sign`
# - `SignedMWK`
# - `SignedUSD`
#
# Then compute trade balance by `date`.

# %%
# Exercise C workspace
# Write your code below.

# %% [markdown]
# ## D) Unit-value placeholder
#
# If later the dataset includes `Quantity` and/or `NetWeightKg`, compute price-like features:
# - `unit_value_usd = USDValue / Quantity`
# - `unit_value_usd_per_kg = USDValue / NetWeightKg`

# %%
# Exercise D workspace
# Write your code below.

# %% [markdown]
# ## E) HS grouping features
#
# Create product hierarchy fields:
# - `HS2`
# - `HS4`
#
# Then produce simple summaries:
# - top HS2 by imports
# - top HS2 by exports

# %%
# Exercise E workspace
# Write your code below.

# %% [markdown]
# ## Final QC checklist
#
# Before finishing, verify:
# 1. For 2024 rows, no unexpected nulls in `MWK_per_USD`, `USDValue`, `date`, `flow_sign`.
# 2. `SignedUSD` has both positive and negative values.
# 3. `HS2` and `HS4` look valid.

# %%
# Final QC workspace
# Write your checks below.
