# %% [markdown]
# ## Exercise 1.5 - Population Statistics Calculator ~15 min
#
# ### Scenario
#
# You are a Junior Statistician at the Datania National Statistics Office (DNSO). Dr. Amara Mwanza has asked you to prepare some basic population statistics for an upcoming report. You need to store key demographic figures in variables, perform some basic calculations, and display the results in a clear format.
#
# ### Dataset
#
# No external dataset needed - you will create variables with the following Datania population data:
#
# - Total population: 18,500,000
# - Urban population: 7,955,000
# - Rural population: 10,545,000
# - Census year: 2020
# - Annual growth rate: 2.87% (as a decimal: 0.0287)
#
# ### Tasks
#
# 1. Create variables to store each of the population figures listed above. Use descriptive `snake_case` names.
# 2. Calculate the urbanization rate (urban population / total population) and store it in a variable.
# 3. Calculate the projected population for 2025 using the formula: `projected = current * (1 + growth_rate) ** years`
# 4. Print each result with a clear label using f-strings. Format the urbanization rate as a percentage with one decimal place.
# 5. Use the `type()` function to verify and print the data type of at least two of your variables.

# %%
# Exercise 1.5 - Population Statistics Calculator
# Datania National Statistics Office

# Task 1: Create variables for population data
total_population = ____
urban_population = ____
rural_population = ____
census_year = ____
growth_rate = ____  # Store as decimal (e.g., 2.87% = 0.0287)

# %%
# Task 2: Calculate urbanization rate
# YOUR CODE HERE
urbanization_rate = ____

# %%
# Task 3: Calculate projected population for 2025
years_ahead = 5
# YOUR CODE HERE
projected_population_2025 = ____

# %%
# Task 4: Print results with clear labels
# Hint: Use f-strings and format the urbanization rate as percentage
print(f"Datania Population Statistics ({census_year} Census)")
print("=" * 45)
# YOUR CODE HERE - print total population
# YOUR CODE HERE - print urban population
# YOUR CODE HERE - print rural population
# YOUR CODE HERE - print urbanization rate as percentage
# YOUR CODE HERE - print projected 2025 population

# %%
# Task 5: Verify data types
print("\nData Type Verification:")
# YOUR CODE HERE - print type of at least two variables

# %% [markdown]
# **Expected output format:**
#
# ```text
# Datania Population Statistics (2020 Census)
# =============================================
# Total Population: 18,500,000
# Urban Population: 7,955,000
# Rural Population: 10,545,000
# Urbanization Rate: 43.0%
# Projected Population (2025): 21,315,XXX
#
# Data Type Verification:
# total_population: <class 'int'>
# growth_rate: <class 'float'>
# ```
