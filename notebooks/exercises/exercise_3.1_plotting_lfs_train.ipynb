# %%
import os
from pprint import pprint

import pandas as pd
import numpy as np
import pyreadstat
import plotly.graph_objects as go
import plotly.io as pio
from plotly.subplots import make_subplots

# %%
# --- Shared color palette (module 3.3) ---
PALETTE = ["#7BB3B2","#65A6BD","#C997AF","#B8B0D3","#F4CF97","#98B9A0","#F6DECD"]

# --- Plotly template: set once, every chart inherits it (module 3.10, Principle 5) ---
nso_template = go.layout.Template()
nso_template.layout = go.Layout(
    font=dict(family='Arial', size=13, color='#333'),
    title_font=dict(size=16, color='#222'),
    plot_bgcolor='white',
    paper_bgcolor='white',
    colorway=PALETTE,
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=True, gridcolor='lightgray', gridwidth=0.5),
    legend=dict(orientation='h', yanchor='bottom', y=1.02, xanchor='left', x=0),
    margin=dict(l=60, r=30, t=60, b=40)
)
pio.templates['nso'] = nso_template
pio.templates.default = 'nso'

# %%
# --- Plotly toolbar config ---
PLOTLY_CONFIG = {
    'displaylogo': False,
    'modeBarButtonsToRemove': ['select2d', 'lasso2d', 'autoScale2d'],
    'toImageButtonOptions': {'format': 'png', 'width': 1200, 'height': 700, 'scale': 2}
}

# %%
# %% [Load data]
df, metadata = pyreadstat.read_sav('../../data/zambia/ZM_LFS_DATASET2024_Annual_10percent.sav')

# %%
# %% [Inspect column labels]
print(set(metadata.column_labels))

# %%
# %% [Select columns of interest]
# This cell was written after investigating the above result and picking
# column names that were likely to contain interesting data

cols = [
    # --- Demographics & Background ---
    "Is ... Male or Female?",
    "How old was ... at (his/her) last birthday?",
    "What is the highest grade/level of education that ... has successfully completed?",
    "What is ...'s current marital status?",
    "What is ...'s relationship to the head of the household?",
    "1. Province",
    "2. District",

    # --- Employment & Work ---
    "In the main job/business that (NAME) has, is she/he...",
    "INDUSTRY",
    "Occupation",
    "How many hours does (NAME) usually work per week in his/her...? Main job",
    "How many hours does (NAME) usually work per week in his/her...? OVERALL TOTAL",
    "What is the frequency of .....'s income/earnings in his/her main job?",
    "Would (NAME) want to work more hours per week than usually worked, provided the extra hours are paid?",
    "Is ?. employed on the basis of a written contract or an oral agreement?",

    # --- Income & Earnings ---
    "What is your annually/monthly/weekly/daily/hourly wage or salary before deductions?",
    "What are your annual/monthly/weekly/daily/hourly earnings after expenses?",
    "At what age did NAME start work for the first time in his /her life",

    # --- Time Use: Household Activities ---
    "During the last 7 days how much time did  (NAME) spend on Cleaning the house, washing clothes, cooking or shopping for the household",
    "During the last 7 days how much time did  (NAME) spend on Fetching water from natural or public sources for use by the household",
    "During the last 7 days how much time did (NAME) spend on Collecting firewood or other natural products for use as fuel by the household",
    "In the last 7 days, how much time did (NAME) spend on Leisure e.g., playing sports, watching TV etc.?",
    "In the last 7 days, how much time did (NAME) spend on Personal care e.g bathing, eating and sleeping?",
    "In the last 7 days, how much time did name spend travelling from home to\xa0place\xa0of\xa0work",

    # --- Time Use: Hours by Day of Week (Main Job) ---
    "Thinking about the last 7 Days, how many hours  ?? work his/her on Monday Main job?",
    "Thinking about the last 7 Days, how many hours  ?? work his/her on Tuesday Main job?",
    "Thinking about the last 7 Days, how many hours  ?? work his/her on Wednesday Main job?",
    "Thinking about the last 7 Days, how many hours  ?? work his/her on Thursday Main job?",
    "Thinking about the last 7 Days, how many hours  ?? work his/her on Friday Main job?",
    "Thinking about the last 7 Days, how many hours  ?? work his/her on Saturday Main job?",
    "Thinking about the last 7 Days, how many hours  ?? work his/her on Sunday Main job?",

    # --- Financial Inclusion ---
    "P.20. Do you own a mobile phone",
    "P.21. Do you have a mobile money account in your own name",
    "P.23. How often do you use mobile money?",
    "P.25.  On a scale of 1 to 4, Do you find mobile money services to be cheap or expensive?",
    "P.30.A Savings at a bank",
    "P.30.G.Savings with savings group",
    "P.30.D.Savings that you keep on your mobile phone",
    "What method do you mainly use to pay for food/groceries?",

    # --- Education ---
    "Can... read and write in any language?",
    "Has... ever attended school?",
    "Is (NAME) currently attending school?",
    "Have (NAME) ever repeated any level of schooling any point in time?",
    "At what age did (NAME) begin school?",
]

# For each label we pick the original column name as it appears in df.
names_to_labels = metadata.column_names_to_labels
names_to_labels_reduced = {}
names = []
for col in cols:
    for name, label in names_to_labels.items():
        if label != col:
            continue
        names.append(name)
        names_to_labels_reduced[name] = label
pprint(names_to_labels_reduced)

# %%
# %% [Filter dataframe to columns of interest]
df = df[names]

# %%
# %% [Extract value labels from metadata]
variable_value_labels = metadata.variable_value_labels

# %%
# %% [Chart 1: Age Distribution — Histogram]
# Pattern: Distribution
# Structure: single Histogram trace + layout

# ----- Step 1: Prepare -----
# Select the age variable from the dataframe and remove missing values

# Calculate the median age for the reference line

# ----- Step 2: Create the figure -----
# Create a new Plotly figure with one histogram trace
# Use age on the x-axis
# Set the number of bins
# Set the bar colour
# Give the trace a legend name

# ----- Step 3: Add a reference line -----
# Add a vertical line at the median age
# Make the line dashed and red
# Add an annotation showing the median value
# Position the annotation near the top right

# ----- Step 4: Format the layout -----
# Add the chart title
# Add the x-axis title
# Add the y-axis title

# ----- Step 5: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 2: Age Pyramid — Two Horizontal Bar Traces]
# Pattern: Comparison with multiple traces
# Structure: two horizontal Bar traces on one figure

# ----- Step 1: Prepare -----
# Create the bin edges for 5-year age groups

# Create the age-group labels for those bins

# Keep only the gender and age columns, remove missing values, and make a copy

# Create a new age_group column by binning ages into the 5-year groups

# Replace the gender codes in A2 with their value labels

# Count the number of males in each age group

# Count the number of females in each age group

# ----- Step 2: Create the figure -----
# Create an empty Plotly figure

# Add the first horizontal bar trace for males
# Use age groups on the y-axis
# Use negative counts on the x-axis so the bars go to the left
# Set the trace name
# Set the orientation to horizontal
# Set the bar colour

# Add the second horizontal bar trace for females
# Use age groups on the y-axis
# Use positive counts on the x-axis so the bars go to the right
# Set the trace name
# Set the orientation to horizontal
# Set the bar colour

# ----- Step 3: Format the layout -----
# Add the chart title

# Add the x-axis title

# Set the bar mode so the two traces meet in the middle

# Adjust the gap between bars

# Set the figure height

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 3: Population by Gender — Pie / Donut]
# Pattern: Composition
# Structure: single Pie trace + layout

# ----- Step 1: Prepare -----
# Take the gender variable, map the coded values to their labels, and count how many observations fall in each category

# ----- Step 2: Create the figure -----
# Create a new Plotly figure with one pie trace

# Add the category labels

# Add the counts as the values

# Turn it into a donut chart by setting the hole size

# Set the slice colours and add white borders between slices

# Show both the percentage and the label on the chart

# ----- Step 3: Format the layout -----
# Add the chart title

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 4: Highest Education Level — Horizontal Bar]
# Pattern: Comparison
# Structure: single horizontal Bar trace + layout

# ----- Step 1: Prepare -----
# Take the education variable, map the coded values to their labels, count the number of observations in each category, and sort the result

# ----- Step 2: Create the figure -----
# Create a new Plotly figure with one horizontal bar trace

# Put the education categories on the y-axis

# Put the counts on the x-axis

# Set the bar orientation to horizontal

# Set the bar colour

# Add the counts as text labels on the bars

# Position the text labels outside the bars

# ----- Step 3: Format the layout -----
# Add the chart title

# Add the x-axis title

# Set the figure height so it grows when there are many categories

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 5: Employment Overview — 2x2 Subplots]
# Pattern: multiple views in one figure
# Structure: one subplot figure with one trace per panel

# ----- Step 1: Prepare -----
# Take the contract-type variable, map the coded values to their labels, and count the number of observations in each category

# Take the industry variable, map the coded values to their labels, count the number of observations in each category, and keep the top 10

# Take the occupation variable, map the coded values to their labels, count the number of observations in each category, and keep the top 10

# Take the wants-more-work-hours variable, map the coded values to their labels, and count the number of observations in each category

# ----- Step 2: Create the subplot figure -----
# Create a 2 by 2 subplot layout

# Add subplot titles for each panel

# Set the subplot types so the first three panels are bar charts and the last panel is a pie chart

# ----- Step 3: Add traces -----
# Add a horizontal bar trace for contract type in row 1, column 1
# Put categories on the y-axis
# Put counts on the x-axis
# Set the orientation to horizontal
# Set the bar colour
# Hide the legend

# Add a horizontal bar trace for top industries in row 1, column 2
# Put categories on the y-axis
# Put counts on the x-axis
# Set the orientation to horizontal
# Set the bar colour
# Hide the legend

# Add a horizontal bar trace for top occupations in row 2, column 1
# Put categories on the y-axis
# Put counts on the x-axis
# Set the orientation to horizontal
# Set the bar colour
# Hide the legend

# Add a pie trace for wants-more-work-hours in row 2, column 2
# Use the category labels
# Use the counts as values
# Set the slice colours
# Show percentage and label text
# Hide the legend

# ----- Step 4: Format the layout -----
# Add the overall figure title

# Set the overall figure height

# ----- Step 5: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 6: Population by Province — Vertical Bar]
# Pattern: Comparison
# Structure: single vertical Bar trace + layout

# ----- Step 1: Prepare -----
# Count the number of observations in each province

# Sort the provinces from highest count to lowest count

# ----- Step 2: Create the figure -----
# Create a new Plotly figure with one vertical bar trace

# Put the province categories on the x-axis

# Put the counts on the y-axis

# Set the bar colour

# ----- Step 3: Format the layout -----
# Add the chart title

# Add the y-axis title

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 7: Hours Worked per Week — Histogram + Box Subplots]
# Pattern: distribution + grouped comparison
# Structure: subplot figure with a histogram in one panel and box plots in the other

# ----- Step 1: Prepare -----
# Select the hours-worked variable and remove missing values

# Calculate the median number of hours for the reference line

# Get the value-label mapping for gender

# Keep only the gender and hours-worked columns, remove missing values, and make a copy

# Create a new Gender column by mapping the coded gender values to their labels

# ----- Step 2: Create the subplot figure -----
# Create a figure with 1 row and 2 columns of subplots

# Add subplot titles for the two panels

# ----- Step 3: Add the histogram -----
# Add a histogram trace to the first subplot
# Use hours worked on the x-axis
# Set the number of bins
# Set the bar colour
# Give the trace a name
# Hide the legend

# ----- Step 4: Add the box plots -----
# Loop through each gender category

# For each gender, filter the data to that group and keep the hours-worked values

# Add a box plot trace for that gender to the second subplot
# Use the subset of hours as the y-values
# Set the trace name to the gender label
# Set the colour for each box plot

# ----- Step 5: Add the reference line -----
# Add a vertical reference line at the median hours value in the histogram subplot

# Make the line dashed and red

# Add an annotation showing the median value in hours

# ----- Step 6: Format the layout and axes -----
# Add the overall figure title

# Add the x-axis title for the histogram subplot

# Add the y-axis title for the histogram subplot

# Add the y-axis title for the box-plot subplot

# ----- Step 7: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 8: Time Use — Stacked Horizontal Bar]
# Pattern: Composition
# Structure: one horizontal Bar trace per activity, stacked in one figure

# ----- Step 1: Prepare -----
# Create a list of the time-use variable names we want to include

# Create a list of readable labels for those activities

# Convert the selected columns to numeric values and calculate the average time for each activity

# ----- Step 2: Create the figure -----
# Create an empty Plotly figure

# Loop through the activity labels, average values, and colours together

# For each activity, add one horizontal bar trace
# Use a single y-category so all activities stack into one bar
# Use the average time as the x-value
# Set the trace name to the activity label
# Set the orientation to horizontal
# Set the bar colour

# ----- Step 3: Format the layout -----
# Add the chart title

# Add the x-axis title

# Set the bar mode to stack so the activity segments build one combined bar

# Set the figure height

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 9: Hours by Day x Gender — Heatmap]
# Pattern: Heatmap
# Structure: single Heatmap trace + layout

# ----- Step 1: Prepare -----
# Create a dictionary that maps day names to the corresponding survey variables

# Get the value-label mapping for gender

# Keep only the gender column and the selected day columns, then make a copy

# Rename the day columns so they use readable day names

# Loop through each day column

# Convert the values in that column to numeric

# Keep only values between 0 and 24 hours and set anything else to missing

# Create a Gender column by mapping the coded gender values to their labels
# If a label is missing, fall back to the original coded value as text

# Reshape the data from wide format to long format
# Keep Gender as the identifier
# Turn the day columns into one Day column and one Hours column
# Remove rows where Hours is missing

# Create a pivot table with Gender as rows, Day as columns, and average Hours as values

# Reorder the columns so the days appear in the correct weekday order

# ----- Step 2: Create the figure -----
# Create a new Plotly figure with one heatmap trace

# Use the pivot-table values as the z matrix

# Put the day names on the x-axis

# Put the gender categories on the y-axis

# Add rounded hour values as text labels inside the cells

# Format the text labels to one decimal place

# Set the colour scale

# Add a colour bar title

# ----- Step 3: Format the layout -----
# Add the chart title

# Set the figure height

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 10: Mobile Money Usage by Gender — Grouped Bar]
# Pattern: Comparison, grouped
# Structure: one Bar trace per gender, grouped in one figure

# ----- Step 1: Prepare -----
# Create a small helper function that maps coded survey values to their value labels for a given column

# Keep only the gender column and the mobile-money-usage column, remove missing values, and make a copy

# Create a Gender column by applying the value labels for the gender variable

# Create a Usage column by applying the value labels for the mobile-money-usage variable

# Create the desired display order for the usage categories from the value labels

# Build a cross-tabulation of usage category by gender

# Reorder the rows to match the intended category order

# Remove rows where all values are missing

# ----- Step 2: Create the figure -----
# Create an empty Plotly figure

# Loop through each gender category in the cross-tabulation

# For each gender, add one bar trace
# Put the usage categories on the x-axis
# Put the counts for that gender on the y-axis
# Set the trace name to the gender label
# Set the bar colour

# ----- Step 3: Format the layout -----
# Add the chart title

# Add the y-axis title

# Set the bar mode to group so the gender bars appear side by side within each usage category

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 11: Perceived Cost of Mobile Money — Diverging Bar]
# Pattern: Comparison with direction
# Structure: multiple horizontal Bar traces with relative stacking

# ----- Step 1: Prepare -----
# Choose the variable for perceived cost of mobile money

# Get the value labels for that variable

# Create the category order from the coded values

# Create a list of readable category labels in that order

# Calculate the percentage of respondents in each category

# Reindex the result so all categories appear in the intended order

# Convert the shares to percentages

# Create a list of colours for the diverging categories

# ----- Step 2: Create the figure -----
# Create an empty Plotly figure

# Loop through the category labels, percentages, and colours together

# For the first two categories, make the values negative so the bars extend to the left

# For the remaining categories, keep the values positive so the bars extend to the right

# Add one horizontal bar trace for each response category
# Use a single y-category so all segments appear on one diverging bar
# Use the signed value on the x-axis
# Set the trace name
# Set the orientation to horizontal
# Set the bar colour

# Add percentage labels inside the bars only when the segment is large enough to fit the text

# Set the text colour so it is readable inside the bars

# ----- Step 3: Add the centre reference line -----
# Add a vertical line at zero to separate the negative and positive sides

# ----- Step 4: Format the layout -----
# Add the chart title

# Add the x-axis title

# Set the bar mode to relative so the negative and positive segments stack from the centre

# Set the figure height

# ----- Step 5: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 12: Savings Methods — Stacked Horizontal Bar]
# Pattern: Composition
# Structure: two horizontal Bar traces, stacked in one figure

# ----- Step 1: Prepare -----
# Create a list of the savings-method variables we want to compare

# Create an empty list to store one summary row per savings method

# Loop through each savings-method variable

# For each variable, get its value labels

# Map the coded values to labels, fall back to the original values if needed, convert to text, clean the text, and standardise to lowercase

# Count how many responses are Yes

# Count how many responses are No

# Add one summary row with the method name, the Yes count, and the No count

# Turn the list of rows into a dataframe and set the method column as the index

# Convert the Yes and No counts into row percentages so each method sums to 100

# ----- Step 2: Create the figure -----
# Create an empty Plotly figure

# Add the first horizontal bar trace for Yes
# Put the method names on the y-axis
# Put the Yes percentages on the x-axis
# Set the trace name
# Set the orientation to horizontal
# Set the bar colour
# Add percentage labels inside the bars
# Set the text colour so the labels are readable

# Add the second horizontal bar trace for No
# Put the method names on the y-axis
# Put the No percentages on the x-axis
# Set the trace name
# Set the orientation to horizontal
# Set the bar colour

# ----- Step 3: Format the layout -----
# Add the chart title

# Add the x-axis title

# Set the x-axis range from 0 to 100

# Set the bar mode to stack so Yes and No form one full bar for each method

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config

# %%
# %% [Chart 13: Hours Worked vs Weekly Wage — Scatter]
# Pattern: Relationship
# Structure: single Scatter trace with mode='markers' + layout

# ----- Step 1: Prepare -----
# Define the column names for hours worked, wage, and wage frequency

# Get the value labels for the wage-frequency variable

# Map the wage-frequency codes to text labels and convert them to lowercase

# Create a list of the day columns that will help us estimate how many days were worked

# Count how many days each person worked by checking which day columns are greater than zero

# Standardize all wages to a weekly wage
# If the wage is annual, divide by 52
# If the wage is monthly, convert it to weekly
# If the wage is already weekly, keep it as it is
# If the wage is daily, multiply it by the number of days worked
# If the wage is hourly, multiply it by hours worked per week
# Use missing values when the frequency cannot be identified

# Create a plotting dataframe with hours worked

# Add the standardized weekly wage to the plotting dataframe

# Replace infinite values with missing values and remove rows with missing data

# Keep only rows where hours worked and weekly wage are both greater than zero

# ----- Step 2: Create the figure -----
# Create a new Plotly figure with one scatter trace

# Put hours worked on the x-axis

# Put standardized weekly wage on the y-axis

# Set the scatter mode to markers

# Set the marker colour, size, and transparency

# Give the trace a name

# ----- Step 3: Format the layout -----
# Add the chart title

# Add the x-axis title

# Add the y-axis title

# Set the y-axis to a log scale because wages are skewed

# ----- Step 4: Display the chart -----
# Show the figure using the standard Plotly config
