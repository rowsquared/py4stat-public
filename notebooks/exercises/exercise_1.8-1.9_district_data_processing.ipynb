# %% [markdown]
# ## Exercise 1.8-1.9 - District Data Processing ~20 min
#
# ### Scenario
#
# Fatima Okonkwo, the Survey Manager at DNSO, has asked you to help organize district-level data for an upcoming field operation. You need to work with lists of districts, their target sample sizes, and compute various statistics using loops. This exercise combines list operations with for and while loops.
#
# ### Dataset
#
# No external dataset needed - you will work with the following district data:

# %%
districts = ["Numerica Urban", "Median Urban", "Polaris District", "Outlier Coastal", "Deviation District"]
target_samples = [500, 450, 300, 350, 280]

# %% [markdown]
# ### Tasks
#
# 1. Create a list of districts and their target samples. Add a new district "Port Sample" with target 320 to both lists.
# 2. Use a `for` loop with `enumerate()` to print each district with its number and target sample.
# 3. Use a `for` loop with `zip()` to calculate and print the total target sample across all districts.
# 4. Use a list comprehension to create a new list containing only districts with targets above 300.
# 5. Use a `while` loop to simulate collecting responses until a target is reached.
# 6. Use `range()` to generate a list of census years from 1960 to 2020 (every 10 years).

# %%
# Exercise 1.8-1.9 - District Data Processing
# Datania National Statistics Office

# Initial data
districts = ["Numerica Urban", "Median Urban", "Polaris District", "Outlier Coastal", "Deviation District"]
target_samples = [500, 450, 300, 350, 280]

# Task 1: Add a new district
print("Task 1: Adding New District")
print("-" * 35)
# YOUR CODE HERE - add "Port Sample" to districts list
# YOUR CODE HERE - add 320 to target_samples list
districts.____
target_samples.____
print(f"Districts: {districts}")
print(f"Targets: {target_samples}")

# %%
# Task 2: Print numbered list using enumerate()
print("\nTask 2: Numbered District List")
print("-" * 35)
# YOUR CODE HERE - use enumerate to print "1. Numerica Urban" etc.
for ____, ____ in enumerate(districts, start=1):
    print(f"{____}. {____}")

# %%
# Task 3: Calculate total using zip()
print("\nTask 3: Total Sample Size Calculation")
print("-" * 40)
total_sample = 0
# YOUR CODE HERE - loop through districts and targets together
for district, target in zip(____, ____):
    print(f"  {district}: {target}")
    total_sample += target

print(f"\nTotal target sample: {total_sample}")

# %%
# Task 4: Filter using list comprehension
print("\nTask 4: Districts with Target > 300")
print("-" * 40)
# YOUR CODE HERE - create list of (district, target) pairs where target > 300
large_districts = [____ for district, target in zip(districts, target_samples) if ____]
print("Large districts (target > 300):")
for item in large_districts:
    print(f"  {item}")

# %%
# Task 5: Simulate data collection with while loop
print("\nTask 5: Data Collection Simulation")
print("-" * 40)
collected = 0
target = 100
day = 0

while ____:  # Continue until target is reached
    day += 1
    # Simulate collecting 15-25 responses per day
    daily_collection = 20  # Simplified for this exercise
    collected += daily_collection
    print(f"Day {day}: Collected {daily_collection}, Total: {collected}")

    if collected >= target:
        print(f"\nTarget of {target} reached in {day} days!")
        break

# %%
# Task 6: Generate census years using range()
print("\nTask 6: Census Years")
print("-" * 25)
# YOUR CODE HERE - create list of years from 1960 to 2020, step 10
census_years = list(range(____, ____, ____))
print(f"Datania Census Years: {census_years}")

# %% [markdown]
# **Expected output:**
#
# ```text
# Task 1: Adding New District
# -----------------------------------
# Districts: ['Numerica Urban', 'Median Urban', 'Polaris District', 'Outlier Coastal', 'Deviation District', 'Port Sample']
# Targets: [500, 450, 300, 350, 280, 320]
#
# Task 2: Numbered District List
# -----------------------------------
# 1. Numerica Urban
# 2. Median Urban
# ...
#
# Task 3: Total Sample Size Calculation
# ----------------------------------------
#   Numerica Urban: 500
#   Median Urban: 450
#   ...
#
# Total target sample: 2200
#
# Task 4: Districts with Target > 300
# ----------------------------------------
# Large districts (target > 300):
#   ('Numerica Urban', 500)
#   ('Median Urban', 450)
#   ('Outlier Coastal', 350)
#   ('Port Sample', 320)
#
# Task 5: Data Collection Simulation
# ----------------------------------------
# Day 1: Collected 20, Total: 20
# Day 2: Collected 20, Total: 40
# ...
# Target of 100 reached in 5 days!
#
# Task 6: Census Years
# -------------------------
# Datania Census Years: [1960, 1970, 1980, 1990, 2000, 2010, 2020]
# ```
