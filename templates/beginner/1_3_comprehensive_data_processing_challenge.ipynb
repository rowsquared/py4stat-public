# %%
import random
from typing import List, Dict, Any

# Sample survey data
random.seed(2024)

def generate_sample_data(n: int = 50) -> List[Dict[str, Any]]:
    """Generate sample household survey data."""
    districts = ["Numerica", "Polaris", "Median City", "Outlier Bay", "Deviation"]
    occupations = ["Farmer", "Teacher", "Trader", "Civil Servant", "Unemployed"]

    data = []
    for i in range(n):
        data.append({
            "household_id": f"HH{i+1:04d}",
            "district": random.choice(districts),
            "members": random.randint(1, 12),
            "income": random.randint(5000, 150000),
            "occupation_head": random.choice(occupations),
            "has_electricity": random.choice([True, False]),
            "has_water": random.choice([True, False])
        })
    return data

households = generate_sample_data(50)

# Task 1: Create a function that calculates per capita income
# Return None if members is 0
def per_capita_income(household: Dict) -> float:
    # Your code here:
    pass


# Task 2: Add per_capita field to all households using list comprehension
# Your code here:


# Task 3: Create a generator that yields households below poverty line
# (per capita income < 15000)
def poor_households(data: List[Dict]) -> ...:
    # Your code here:
    pass


# Task 4: Calculate statistics by district
# - Count of households
# - Average income
# - Percentage with electricity
def district_statistics(data: List[Dict]) -> Dict[str, Dict]:
    # Your code here:
    pass


# Task 5: Sort households by income and get top 10
# Your code here:


# Task 6: Use filter and map to get unique occupations of household heads
# with income > 50000
# Your code here:


# Print your results
print("=== Survey Analysis Results ===")
# Out:
# === Survey Analysis Results ===
