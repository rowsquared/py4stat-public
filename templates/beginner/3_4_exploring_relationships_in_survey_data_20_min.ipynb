# %%
import pandas as pd
import matplotlib.pyplot as plt
import datania

# Load the data
qlfs_data = datania.generate_labour_force_survey(n_persons=1200, seed=456)
df = pd.read_csv(qlfs_data)

# Filter to employed persons with valid data
employed = df[
    (df['employment_status'] == 'Employed') &
    (df['monthly_income'].notna()) &
    (df['hours_worked'].notna())
].copy()

print(f"Employed persons with complete data: {len(employed)}")

# Task 1: Scatter plot and correlation
# Create scatter plot of hours_worked vs monthly_income
# Calculate correlation coefficient
# YOUR CODE HERE


# Task 2: Income by education level
# Calculate mean income by education_level
# Create a grouped boxplot
# YOUR CODE HERE
# Out:
# Employed persons with complete data: 759
# Pearson correlation (hours_worked, monthly_income): 0.015
# Spearman correlation (hours_worked, monthly_income): 0.025
#
# Mean monthly income by education level:
# education_level
# Tertiary     64030.619835
# Secondary    41981.792517
# Primary      36433.557312
# Name: monthly_income, dtype: float64
# Cross-tabulation (counts) of education_level vs sector:
# sector           Private  Public
# education_level
# Primary              237      16
# Secondary            263      31
# Tertiary             105      16
#
# Row percentages by education level (rows sum to 100):
# sector           Private  Public
# education_level
# Primary             93.7     6.3
# Secondary           89.5    10.5
# Tertiary            86.8    13.2
#
# Tertiary — percent in public sector: 13.2%
# Average percent in public sector (other education levels): 8.4%
# Conclusion: In this sample, tertiary-educated workers are MORE likely to be in the public sector.
