# %%
import pandas as pd
import datania

# Load the data
qlfs_data = datania.generate_labour_force_survey(n_persons=1500, seed=123)
df = pd.read_csv(qlfs_data)

# Filter to employed persons with valid income
employed = df[(df['employment_status'] == 'Employed') & (df['monthly_income'].notna())].copy()

print(f"Total employed persons with income: {len(employed)}")

# Task 1: Average income by province
# Use groupby to calculate mean income per province
# YOUR CODE HERE


# Task 2: Multiple statistics with .agg()
# Calculate mean, median, and count for each province
# YOUR CODE HERE


# Task 3: Pivot table - income by province and urban/rural
# Create a pivot table with provinces as rows and urban_rural as columns
# YOUR CODE HERE


# Task 4: Check sample sizes
# Find combinations with fewer than 30 observations
# Hint: Use groupby with both province and urban_rural, then filter
# YOUR CODE HERE
