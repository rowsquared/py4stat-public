# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import datania

# Load the agricultural survey data
farms_csv = datania.generate_agricultural_survey(n_farms=200, seed=42)
farms = pd.read_csv(farms_csv)

print("Columns:", farms.columns.tolist())
print(f"\nFirst few rows:")
farms.head()
# Task 1: Identify which columns contain the coordinates
# YOUR CODE HERE - inspect the data to find lat/lon columns
# Task 2: Create Point geometries
# IMPORTANT: Point() takes (longitude, latitude) - X before Y!
# YOUR CODE HERE
geometry = # Create a list of Point objects
# Task 3: Convert to GeoDataFrame
# YOUR CODE HERE
farms_gdf = # Create GeoDataFrame with geometry and CRS

print(farms_gdf.head())
print(f"\nCRS: {farms_gdf.crs}")
# Task 4: Visual check - plot the points
# If coordinates are correct, points should cluster around Datania's location
fig, ax = plt.subplots(figsize=(10, 8))

# YOUR CODE HERE - plot the GeoDataFrame

plt.title('DAPS Farm Locations - Visual Check')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Task 5: Save as GeoPackage
# YOUR CODE HERE

print("File saved successfully!")
