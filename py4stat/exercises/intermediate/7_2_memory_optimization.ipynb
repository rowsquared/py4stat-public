# %%
from py4stat import datania
import pandas as pd

# Task 1: Load data with default types and diagnose
csv_file = datania.generate_census_data(n_persons=100000, seed=42)
df_original = pd.read_csv(csv_file)

print("=== ORIGINAL MEMORY USAGE ===")
# YOUR CODE HERE: Use df.info() with the right parameter


# Task 2: Create optimized dtype dictionary
# Hint: Look at the columns - which ones have few unique values?
# Hint: What's the maximum value in the 'age' column?

dtypes_optimized = {
    # YOUR CODE HERE: Map column names to efficient types
    # Example: 'province': 'category',
    # Example: 'age': 'int8',
}


# Task 3: Reload with optimized types
csv_file = datania.generate_census_data(n_persons=100000, seed=42)  # Regenerate
df_optimized = pd.read_csv(csv_file, dtype=dtypes_optimized)

print("\n=== OPTIMIZED MEMORY USAGE ===")
# YOUR CODE HERE: Check memory usage of optimized DataFrame


# Task 4: Calculate improvement
# Hint: You can get memory in bytes with df.memory_usage(deep=True).sum()

original_memory = df_original.memory_usage(deep=True).sum() / (1024**2)  # MB
optimized_memory = # YOUR CODE HERE

reduction_pct = # YOUR CODE HERE

print(f"\n=== RESULTS ===")
print(f"Original: {original_memory:.2f} MB")
print(f"Optimized: {optimized_memory:.2f} MB")
print(f"Reduction: {reduction_pct:.1f}%")
