# %%
import pandas as pd
from py4stat import datania

# Load labour force survey data
qlfs_data = datania.generate_labour_force_survey(n_persons=1200, seed=42)
df = pd.read_csv(qlfs_data)

# Preview the data
print(df.head())
print(f"\nEmployment status values: {df['employment_status'].unique()}")
print(f"Provinces: {df['province'].unique()}")

# Filter to employed persons for income analysis
employed = df[df['employment_status'] == 'Employed'].copy()
print(f"\nEmployed persons: {len(employed)}")

# Question 1: Distribution of monthly income among employed persons
# What chart type is best for showing the distribution of a single numeric variable?
# YOUR CHART TYPE CHOICE: _____________
# YOUR CODE HERE


# Question 2: Employment status by province
# What chart type is best for comparing categories across groups?
# YOUR CHART TYPE CHOICE: _____________
# YOUR CODE HERE


# Question 3: Relationship between age and monthly income
# What chart type shows the relationship between two numeric variables?
# YOUR CHART TYPE CHOICE: _____________
# YOUR CODE HERE


# Question 4: Proportion of workers by industry sector
# What chart type shows composition (parts of a whole)?
# YOUR CHART TYPE CHOICE: _____________
# Hint: Consider how many categories there are before choosing
# YOUR CODE HERE
