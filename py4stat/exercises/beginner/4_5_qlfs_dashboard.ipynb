# %%
import pandas as pd
from py4stat import datania

# Load the Q1 2026 QLFS data
qlfs_data = datania.generate_labour_force_survey(n_persons=1500, year=2026, quarter=1, seed=42)
df = pd.read_csv(qlfs_data)

# Explore the data
print("Dataset shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nEmployment status breakdown:")
print(df['employment_status'].value_counts())
print("\nProvince breakdown:")
print(df['province'].value_counts())
print("\nEducation levels:")
print(df['education_level'].value_counts())

# Filter employed for income analysis
employed = df[df['employment_status'] == 'Employed'].copy()
print(f"\nEmployed persons: {len(employed)}")
print(f"Income range: {employed['monthly_income'].min():,.0f} - {employed['monthly_income'].max():,.0f} DKW")


# ============================================
# VISUALIZATION 1: Population Pyramid
# ============================================

# Create age groups
age_bins = [15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70, 75, 100]
age_labels = ['15-19', '20-24', '25-29', '30-34', '35-39', '40-44',
              '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75+']

df['age_group'] = pd.cut(df['age'], bins=age_bins, labels=age_labels, right=False)

# Prepare pyramid data
pyramid_data = df.groupby(['age_group', 'sex']).size().unstack(fill_value=0)

# YOUR CODE HERE: Create the population pyramid
# Remember: Males on left (negative values), Females on right (positive values)



# ============================================
# VISUALIZATION 2: Employment by Province
# ============================================

# Prepare data: count by province and employment status
emp_by_province = df.groupby(['province', 'employment_status']).size().reset_index(name='count')

# YOUR CODE HERE: Create a stacked or grouped bar chart
# Consider using color parameter for employment_status
# Use a colorblind-friendly palette: color_discrete_sequence=px.colors.qualitative.Safe



# ============================================
# VISUALIZATION 3: Education to Employment Sankey
# ============================================

# Prepare flow data
flow_data = df.groupby(['education_level', 'employment_status']).size().reset_index(name='count')

# Create node labels
education_levels = flow_data['education_level'].unique().tolist()
employment_statuses = flow_data['employment_status'].unique().tolist()
all_labels = education_levels + employment_statuses

# YOUR CODE HERE: Create source and target indices, then the Sankey diagram
# Hint: source_indices map education levels to their positions in all_labels
# target_indices map employment statuses to their positions (offset by len(education_levels))



# ============================================
# VISUALIZATION 4: Income Distribution
# ============================================

# YOUR CODE HERE: Create a box plot or histogram showing income by province
# Only use employed persons (the 'employed' DataFrame)
# Make sure to include clear labels and title



# ============================================
# EXPORT ALL VISUALIZATIONS
# ============================================

# YOUR CODE HERE: Export each figure as HTML
# Example: fig.write_html("qlfs_q1_2026_pyramid.html")
# Suggested filenames:
# - qlfs_q1_2026_pyramid.html
# - qlfs_q1_2026_employment_by_province.html
# - qlfs_q1_2026_education_employment_sankey.html
# - qlfs_q1_2026_income_distribution.html

print("\n" + "="*50)
print("Dashboard complete! Files exported:")
# print("- qlfs_q1_2026_pyramid.html")
# ... etc
